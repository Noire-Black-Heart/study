# %%
import csv
import pprint
data_Neighbourhoods = list(csv.DictReader(open('Neighbourhoods.csv')))
data_BusinessStats = list(csv.DictReader(open('BusinessStats.csv')))
data_Neighbourhoods
data_BusinessStats
# Out:
# [OrderedDict([('area_id', '102011028'),
#               ('num_businesses', '738'),
#               ('retail_trade', '35'),
#               ('accommodation_and_food_services', '33'),
#               ('health_care_and_social_assistance', '62'),
#               ('education_and_training', '9'),
#               ('arts_and_recreation_services', '20')]),
#  OrderedDict([('area_id', '102011029'),
#               ('num_businesses', '907'),
#               ('retail_trade', '42'),
#               ('accommodation_and_food_services', '21'),
#               ('health_care_and_social_assistance', '43'),
#               ('education_and_training', '11'),
#               ('arts_and_recreation_services', '29')]),
#  OrderedDict([('area_id', '102011030'),
#               ('num_businesses', '1102'),
#               ('retail_trade', '42'),
#               ('accommodation_and_food_services', '17'),
#               ('health_care_and_social_assistance', '11'),
#               ('education_and_training', '18'),
#               ('arts_and_recreation_services', '23')]),
#  OrderedDict([('area_id', '102011031'),
#               ('num_businesses', '1666'),
#               ('retail_trade', '143'),
#               ('accommodation_and_food_services', '68'),
#               ('health_care_and_social_assistance', '164'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '15')]),
#  OrderedDict([('area_id', '102011032'),
#               ('num_businesses', '2126'),
#               ('retail_trade', '159'),
#               ('accommodation_and_food_services', '95'),
#               ('health_care_and_social_assistance', '230'),
#               ('education_and_training', '36'),
#               ('arts_and_recreation_services', '27')]),
#  OrderedDict([('area_id', '102011033'),
#               ('num_businesses', '352'),
#               ('retail_trade', '18'),
#               ('accommodation_and_food_services', '14'),
#               ('health_care_and_social_assistance', '18'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '8')]),
#  OrderedDict([('area_id', '102011034'),
#               ('num_businesses', '479'),
#               ('retail_trade', '31'),
#               ('accommodation_and_food_services', '21'),
#               ('health_care_and_social_assistance', '40'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '102011035'),
#               ('num_businesses', '292'),
#               ('retail_trade', '14'),
#               ('accommodation_and_food_services', '5'),
#               ('health_care_and_social_assistance', '16'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '8')]),
#  OrderedDict([('area_id', '102011036'),
#               ('num_businesses', '477'),
#               ('retail_trade', '22'),
#               ('accommodation_and_food_services', '17'),
#               ('health_care_and_social_assistance', '27'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '102011037'),
#               ('num_businesses', '312'),
#               ('retail_trade', '10'),
#               ('accommodation_and_food_services', '9'),
#               ('health_care_and_social_assistance', '20'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '7')]),
#  OrderedDict([('area_id', '102011038'),
#               ('num_businesses', '486'),
#               ('retail_trade', '32'),
#               ('accommodation_and_food_services', '14'),
#               ('health_care_and_social_assistance', '20'),
#               ('education_and_training', '4'),
#               ('arts_and_recreation_services', '12')]),
#  OrderedDict([('area_id', '102011039'),
#               ('num_businesses', '1351'),
#               ('retail_trade', '66'),
#               ('accommodation_and_food_services', '70'),
#               ('health_care_and_social_assistance', '167'),
#               ('education_and_training', '25'),
#               ('arts_and_recreation_services', '21')]),
#  OrderedDict([('area_id', '102011040'),
#               ('num_businesses', '1217'),
#               ('retail_trade', '73'),
#               ('accommodation_and_food_services', '76'),
#               ('health_care_and_social_assistance', '57'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '23')]),
#  OrderedDict([('area_id', '102011041'),
#               ('num_businesses', '924'),
#               ('retail_trade', '36'),
#               ('accommodation_and_food_services', '31'),
#               ('health_care_and_social_assistance', '66'),
#               ('education_and_training', '12'),
#               ('arts_and_recreation_services', '16')]),
#  OrderedDict([('area_id', '102011042'),
#               ('num_businesses', '691'),
#               ('retail_trade', '53'),
#               ('accommodation_and_food_services', '51'),
#               ('health_care_and_social_assistance', '41'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '10')]),
#  OrderedDict([('area_id', '102011043'),
#               ('num_businesses', '486'),
#               ('retail_trade', '23'),
#               ('accommodation_and_food_services', '30'),
#               ('health_care_and_social_assistance', '43'),
#               ('education_and_training', '12'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '102021044'),
#               ('num_businesses', '1035'),
#               ('retail_trade', '50'),
#               ('accommodation_and_food_services', '32'),
#               ('health_care_and_social_assistance', '59'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '15')]),
#  OrderedDict([('area_id', '102021045'),
#               ('num_businesses', '290'),
#               ('retail_trade', '17'),
#               ('accommodation_and_food_services', '9'),
#               ('health_care_and_social_assistance', '9'),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '102021046'),
#               ('num_businesses', '350'),
#               ('retail_trade', '16'),
#               ('accommodation_and_food_services', '17'),
#               ('health_care_and_social_assistance', '15'),
#               ('education_and_training', '4'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '102021047'),
#               ('num_businesses', '994'),
#               ('retail_trade', '55'),
#               ('accommodation_and_food_services', '24'),
#               ('health_care_and_social_assistance', '51'),
#               ('education_and_training', '17'),
#               ('arts_and_recreation_services', '8')]),
#  OrderedDict([('area_id', '102021048'),
#               ('num_businesses', '816'),
#               ('retail_trade', '65'),
#               ('accommodation_and_food_services', '34'),
#               ('health_care_and_social_assistance', '54'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '12')]),
#  OrderedDict([('area_id', '102021049'),
#               ('num_businesses', '390'),
#               ('retail_trade', '16'),
#               ('accommodation_and_food_services', '6'),
#               ('health_care_and_social_assistance', '15'),
#               ('education_and_training', '4'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '102021050'),
#               ('num_businesses', '424'),
#               ('retail_trade', '26'),
#               ('accommodation_and_food_services', '20'),
#               ('health_care_and_social_assistance', '16'),
#               ('education_and_training', '6'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '102021051'),
#               ('num_businesses', '439'),
#               ('retail_trade', '31'),
#               ('accommodation_and_food_services', '10'),
#               ('health_care_and_social_assistance', '34'),
#               ('education_and_training', '6'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '102021052'),
#               ('num_businesses', '287'),
#               ('retail_trade', '14'),
#               ('accommodation_and_food_services', '11'),
#               ('health_care_and_social_assistance', '10'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '102021053'),
#               ('num_businesses', '1000'),
#               ('retail_trade', '84'),
#               ('accommodation_and_food_services', '79'),
#               ('health_care_and_social_assistance', '54'),
#               ('education_and_training', '11'),
#               ('arts_and_recreation_services', '18')]),
#  OrderedDict([('area_id', '102021054'),
#               ('num_businesses', '588'),
#               ('retail_trade', '47'),
#               ('accommodation_and_food_services', '44'),
#               ('health_care_and_social_assistance', '40'),
#               ('education_and_training', '11'),
#               ('arts_and_recreation_services', '8')]),
#  OrderedDict([('area_id', '102021055'),
#               ('num_businesses', '973'),
#               ('retail_trade', '68'),
#               ('accommodation_and_food_services', '41'),
#               ('health_care_and_social_assistance', '38'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '8')]),
#  OrderedDict([('area_id', '102021056'),
#               ('num_businesses', '768'),
#               ('retail_trade', '44'),
#               ('accommodation_and_food_services', '28'),
#               ('health_care_and_social_assistance', '49'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '102021057'),
#               ('num_businesses', '645'),
#               ('retail_trade', '34'),
#               ('accommodation_and_food_services', '58'),
#               ('health_care_and_social_assistance', '28'),
#               ('education_and_training', '12'),
#               ('arts_and_recreation_services', '12')]),
#  OrderedDict([('area_id', '115011290'),
#               ('num_businesses', '1880'),
#               ('retail_trade', '109'),
#               ('accommodation_and_food_services', '57'),
#               ('health_care_and_social_assistance', '137'),
#               ('education_and_training', '34'),
#               ('arts_and_recreation_services', '28')]),
#  OrderedDict([('area_id', '115011291'),
#               ('num_businesses', '4674'),
#               ('retail_trade', '211'),
#               ('accommodation_and_food_services', '139'),
#               ('health_care_and_social_assistance', '419'),
#               ('education_and_training', '74'),
#               ('arts_and_recreation_services', '40')]),
#  OrderedDict([('area_id', '115011294'),
#               ('num_businesses', '736'),
#               ('retail_trade', '28'),
#               ('accommodation_and_food_services', '11'),
#               ('health_care_and_social_assistance', '59'),
#               ('education_and_training', '6'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '115011296'),
#               ('num_businesses', '1503'),
#               ('retail_trade', '61'),
#               ('accommodation_and_food_services', '26'),
#               ('health_care_and_social_assistance', '134'),
#               ('education_and_training', '25'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '115011553'),
#               ('num_businesses', '1803'),
#               ('retail_trade', '135'),
#               ('accommodation_and_food_services', '35'),
#               ('health_care_and_social_assistance', '86'),
#               ('education_and_training', '48'),
#               ('arts_and_recreation_services', '25')]),
#  OrderedDict([('area_id', '115011554'),
#               ('num_businesses', '389'),
#               ('retail_trade', '21'),
#               ('accommodation_and_food_services', '4'),
#               ('health_care_and_social_assistance', '42'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '115011555'),
#               ('num_businesses', '1347'),
#               ('retail_trade', '80'),
#               ('accommodation_and_food_services', '52'),
#               ('health_care_and_social_assistance', '121'),
#               ('education_and_training', '28'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '115011556'),
#               ('num_businesses', '1169'),
#               ('retail_trade', '71'),
#               ('accommodation_and_food_services', '40'),
#               ('health_care_and_social_assistance', '112'),
#               ('education_and_training', '26'),
#               ('arts_and_recreation_services', '18')]),
#  OrderedDict([('area_id', '115011557'),
#               ('num_businesses', '520'),
#               ('retail_trade', '28'),
#               ('accommodation_and_food_services', '7'),
#               ('health_care_and_social_assistance', '43'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '115011558'),
#               ('num_businesses', '1526'),
#               ('retail_trade', '93'),
#               ('accommodation_and_food_services', '57'),
#               ('health_care_and_social_assistance', '129'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '5')]),
#  OrderedDict([('area_id', '115011559'),
#               ('num_businesses', '1856'),
#               ('retail_trade', '96'),
#               ('accommodation_and_food_services', '56'),
#               ('health_care_and_social_assistance', '152'),
#               ('education_and_training', '29'),
#               ('arts_and_recreation_services', '17')]),
#  OrderedDict([('area_id', '115021297'),
#               ('num_businesses', '3683'),
#               ('retail_trade', '215'),
#               ('accommodation_and_food_services', '86'),
#               ('health_care_and_social_assistance', '141'),
#               ('education_and_training', '51'),
#               ('arts_and_recreation_services', '48')]),
#  OrderedDict([('area_id', '115021298'),
#               ('num_businesses', '816'),
#               ('retail_trade', '41'),
#               ('accommodation_and_food_services', '14'),
#               ('health_care_and_social_assistance', '27'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '17')]),
#  OrderedDict([('area_id', '115031299'),
#               ('num_businesses', '325'),
#               ('retail_trade', '18'),
#               ('accommodation_and_food_services', '12'),
#               ('health_care_and_social_assistance', '3'),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '5')]),
#  OrderedDict([('area_id', '115031300'),
#               ('num_businesses', '2430'),
#               ('retail_trade', '93'),
#               ('accommodation_and_food_services', '47'),
#               ('health_care_and_social_assistance', '59'),
#               ('education_and_training', '34'),
#               ('arts_and_recreation_services', '36')]),
#  OrderedDict([('area_id', '115041301'),
#               ('num_businesses', '1622'),
#               ('retail_trade', '76'),
#               ('accommodation_and_food_services', '38'),
#               ('health_care_and_social_assistance', '28'),
#               ('education_and_training', '13'),
#               ('arts_and_recreation_services', '23')]),
#  OrderedDict([('area_id', '115041302'),
#               ('num_businesses', '2154'),
#               ('retail_trade', '160'),
#               ('accommodation_and_food_services', '77'),
#               ('health_care_and_social_assistance', '117'),
#               ('education_and_training', '38'),
#               ('arts_and_recreation_services', '15')]),
#  OrderedDict([('area_id', '116011303'),
#               ('num_businesses', '2319'),
#               ('retail_trade', '162'),
#               ('accommodation_and_food_services', '91'),
#               ('health_care_and_social_assistance', '142'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '19')]),
#  OrderedDict([('area_id', '116011304'),
#               ('num_businesses', '867'),
#               ('retail_trade', '43'),
#               ('accommodation_and_food_services', '29'),
#               ('health_care_and_social_assistance', '47'),
#               ('education_and_training', '9'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '116011306'),
#               ('num_businesses', '978'),
#               ('retail_trade', '60'),
#               ('accommodation_and_food_services', '38'),
#               ('health_care_and_social_assistance', '55'),
#               ('education_and_training', '11'),
#               ('arts_and_recreation_services', '14')]),
#  OrderedDict([('area_id', '116011307'),
#               ('num_businesses', '2401'),
#               ('retail_trade', '129'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '63'),
#               ('education_and_training', '20'),
#               ('arts_and_recreation_services', '24')]),
#  OrderedDict([('area_id', '116011308'),
#               ('num_businesses', '1616'),
#               ('retail_trade', '106'),
#               ('accommodation_and_food_services', '82'),
#               ('health_care_and_social_assistance', '84'),
#               ('education_and_training', '29'),
#               ('arts_and_recreation_services', '18')]),
#  OrderedDict([('area_id', '116011560'),
#               ('num_businesses', '723'),
#               ('retail_trade', '28'),
#               ('accommodation_and_food_services', '24'),
#               ('health_care_and_social_assistance', '32'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '116011561'),
#               ('num_businesses', '830'),
#               ('retail_trade', '48'),
#               ('accommodation_and_food_services', '41'),
#               ('health_care_and_social_assistance', '32'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '7')]),
#  OrderedDict([('area_id', '116021309'),
#               ('num_businesses', '1236'),
#               ('retail_trade', '102'),
#               ('accommodation_and_food_services', '57'),
#               ('health_care_and_social_assistance', '66'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '116021310'),
#               ('num_businesses', '2116'),
#               ('retail_trade', '166'),
#               ('accommodation_and_food_services', '90'),
#               ('health_care_and_social_assistance', '149'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '20')]),
#  OrderedDict([('area_id', '116021312'),
#               ('num_businesses', '1573'),
#               ('retail_trade', '100'),
#               ('accommodation_and_food_services', '37'),
#               ('health_care_and_social_assistance', '43'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '17')]),
#  OrderedDict([('area_id', '116021562'),
#               ('num_businesses', '257'),
#               ('retail_trade', '22'),
#               ('accommodation_and_food_services', '6'),
#               ('health_care_and_social_assistance', '15'),
#               ('education_and_training', '9'),
#               ('arts_and_recreation_services', '6')]),
#  OrderedDict([('area_id', '116021563'),
#               ('num_businesses', '1246'),
#               ('retail_trade', '79'),
#               ('accommodation_and_food_services', '42'),
#               ('health_care_and_social_assistance', '54'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '17')]),
#  OrderedDict([('area_id', '116031313'),
#               ('num_businesses', '424'),
#               ('retail_trade', '24'),
#               ('accommodation_and_food_services', '15'),
#               ('health_care_and_social_assistance', '19'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '116031314'),
#               ('num_businesses', '600'),
#               ('retail_trade', '34'),
#               ('accommodation_and_food_services', '20'),
#               ('health_care_and_social_assistance', '10'),
#               ('education_and_training', '9'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '116031315'),
#               ('num_businesses', '921'),
#               ('retail_trade', '42'),
#               ('accommodation_and_food_services', '26'),
#               ('health_care_and_social_assistance', '33'),
#               ('education_and_training', '7'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '116031316'),
#               ('num_businesses', '435'),
#               ('retail_trade', '36'),
#               ('accommodation_and_food_services', '13'),
#               ('health_care_and_social_assistance', '17'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '116031317'),
#               ('num_businesses', '1136'),
#               ('retail_trade', '95'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '76'),
#               ('education_and_training', '13'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '116031318'),
#               ('num_businesses', '500'),
#               ('retail_trade', '15'),
#               ('accommodation_and_food_services', '5'),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '116031319'),
#               ('num_businesses', '1194'),
#               ('retail_trade', '81'),
#               ('accommodation_and_food_services', '52'),
#               ('health_care_and_social_assistance', '48'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '6')]),
#  OrderedDict([('area_id', '117011320'),
#               ('num_businesses', '409'),
#               ('retail_trade', '23'),
#               ('accommodation_and_food_services', '5'),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '117011321'),
#               ('num_businesses', '1304'),
#               ('retail_trade', '50'),
#               ('accommodation_and_food_services', '53'),
#               ('health_care_and_social_assistance', '40'),
#               ('education_and_training', '13'),
#               ('arts_and_recreation_services', '18')]),
#  OrderedDict([('area_id', '117011322'),
#               ('num_businesses', '2580'),
#               ('retail_trade', '166'),
#               ('accommodation_and_food_services', '124'),
#               ('health_care_and_social_assistance', '81'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '22')]),
#  OrderedDict([('area_id', '117011323'),
#               ('num_businesses', '911'),
#               ('retail_trade', '62'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '54'),
#               ('education_and_training', '17'),
#               ('arts_and_recreation_services', '18')]),
#  OrderedDict([('area_id', '117011324'),
#               ('num_businesses', '135'),
#               ('retail_trade', '5'),
#               ('accommodation_and_food_services', '3'),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '117011325'),
#               ('num_businesses', '9'),
#               ('retail_trade', ''),
#               ('accommodation_and_food_services', ''),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '117021326'),
#               ('num_businesses', '3109'),
#               ('retail_trade', '238'),
#               ('accommodation_and_food_services', '145'),
#               ('health_care_and_social_assistance', '155'),
#               ('education_and_training', '30'),
#               ('arts_and_recreation_services', '88')]),
#  OrderedDict([('area_id', '117021327'),
#               ('num_businesses', '1917'),
#               ('retail_trade', '117'),
#               ('accommodation_and_food_services', '112'),
#               ('health_care_and_social_assistance', '152'),
#               ('education_and_training', '34'),
#               ('arts_and_recreation_services', '73')]),
#  OrderedDict([('area_id', '117021328'),
#               ('num_businesses', '1087'),
#               ('retail_trade', '78'),
#               ('accommodation_and_food_services', '43'),
#               ('health_care_and_social_assistance', '26'),
#               ('education_and_training', '23'),
#               ('arts_and_recreation_services', '31')]),
#  OrderedDict([('area_id', '117031329'),
#               ('num_businesses', '2260'),
#               ('retail_trade', '150'),
#               ('accommodation_and_food_services', '197'),
#               ('health_care_and_social_assistance', '252'),
#               ('education_and_training', '43'),
#               ('arts_and_recreation_services', '84')]),
#  OrderedDict([('area_id', '117031330'),
#               ('num_businesses', '3218'),
#               ('retail_trade', '249'),
#               ('accommodation_and_food_services', '133'),
#               ('health_care_and_social_assistance', '113'),
#               ('education_and_training', '46'),
#               ('arts_and_recreation_services', '115')]),
#  OrderedDict([('area_id', '117031331'),
#               ('num_businesses', '1830'),
#               ('retail_trade', '114'),
#               ('accommodation_and_food_services', '115'),
#               ('health_care_and_social_assistance', '174'),
#               ('education_and_training', '49'),
#               ('arts_and_recreation_services', '63')]),
#  OrderedDict([('area_id', '117031332'),
#               ('num_businesses', '2316'),
#               ('retail_trade', '170'),
#               ('accommodation_and_food_services', '180'),
#               ('health_care_and_social_assistance', '323'),
#               ('education_and_training', '52'),
#               ('arts_and_recreation_services', '119')]),
#  OrderedDict([('area_id', '117031333'),
#               ('num_businesses', '2874'),
#               ('retail_trade', '139'),
#               ('accommodation_and_food_services', '224'),
#               ('health_care_and_social_assistance', '162'),
#               ('education_and_training', '40'),
#               ('arts_and_recreation_services', '109')]),
#  OrderedDict([('area_id', '117031334'),
#               ('num_businesses', '3933'),
#               ('retail_trade', '214'),
#               ('accommodation_and_food_services', '219'),
#               ('health_care_and_social_assistance', '162'),
#               ('education_and_training', '67'),
#               ('arts_and_recreation_services', '55')]),
#  OrderedDict([('area_id', '117031335'),
#               ('num_businesses', '2350'),
#               ('retail_trade', '124'),
#               ('accommodation_and_food_services', '129'),
#               ('health_care_and_social_assistance', '123'),
#               ('education_and_training', '59'),
#               ('arts_and_recreation_services', '90')]),
#  OrderedDict([('area_id', '117031336'),
#               ('num_businesses', '4302'),
#               ('retail_trade', '227'),
#               ('accommodation_and_food_services', '279'),
#               ('health_care_and_social_assistance', '203'),
#               ('education_and_training', '105'),
#               ('arts_and_recreation_services', '124')]),
#  OrderedDict([('area_id', '117031337'),
#               ('num_businesses', '40285'),
#               ('retail_trade', '1558'),
#               ('accommodation_and_food_services', '1647'),
#               ('health_care_and_social_assistance', '1057'),
#               ('education_and_training', '608'),
#               ('arts_and_recreation_services', '256')]),
#  OrderedDict([('area_id', '117031338'),
#               ('num_businesses', '3597'),
#               ('retail_trade', '294'),
#               ('accommodation_and_food_services', '219'),
#               ('health_care_and_social_assistance', '154'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '71')]),
#  OrderedDict([('area_id', '118011339'),
#               ('num_businesses', '2183'),
#               ('retail_trade', '109'),
#               ('accommodation_and_food_services', '94'),
#               ('health_care_and_social_assistance', '167'),
#               ('education_and_training', '40'),
#               ('arts_and_recreation_services', '96')]),
#  OrderedDict([('area_id', '118011340'),
#               ('num_businesses', '2575'),
#               ('retail_trade', '173'),
#               ('accommodation_and_food_services', '136'),
#               ('health_care_and_social_assistance', '145'),
#               ('education_and_training', '59'),
#               ('arts_and_recreation_services', '111')]),
#  OrderedDict([('area_id', '118011341'),
#               ('num_businesses', '3685'),
#               ('retail_trade', '216'),
#               ('accommodation_and_food_services', '177'),
#               ('health_care_and_social_assistance', '433'),
#               ('education_and_training', '70'),
#               ('arts_and_recreation_services', '80')]),
#  OrderedDict([('area_id', '118011342'),
#               ('num_businesses', ''),
#               ('retail_trade', ''),
#               ('accommodation_and_food_services', ''),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '118011343'),
#               ('num_businesses', '5016'),
#               ('retail_trade', '271'),
#               ('accommodation_and_food_services', '164'),
#               ('health_care_and_social_assistance', '540'),
#               ('education_and_training', '61'),
#               ('arts_and_recreation_services', '93')]),
#  OrderedDict([('area_id', '118011344'),
#               ('num_businesses', '1545'),
#               ('retail_trade', '80'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '134'),
#               ('education_and_training', '28'),
#               ('arts_and_recreation_services', '31')]),
#  OrderedDict([('area_id', '118011345'),
#               ('num_businesses', '2463'),
#               ('retail_trade', '189'),
#               ('accommodation_and_food_services', '97'),
#               ('health_care_and_social_assistance', '183'),
#               ('education_and_training', '42'),
#               ('arts_and_recreation_services', '100')]),
#  OrderedDict([('area_id', '118011346'),
#               ('num_businesses', '1950'),
#               ('retail_trade', '104'),
#               ('accommodation_and_food_services', '64'),
#               ('health_care_and_social_assistance', '170'),
#               ('education_and_training', '30'),
#               ('arts_and_recreation_services', '44')]),
#  OrderedDict([('area_id', '118011347'),
#               ('num_businesses', '1384'),
#               ('retail_trade', '88'),
#               ('accommodation_and_food_services', '34'),
#               ('health_care_and_social_assistance', '152'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '36')]),
#  OrderedDict([('area_id', '118021348'),
#               ('num_businesses', '2567'),
#               ('retail_trade', '111'),
#               ('accommodation_and_food_services', '97'),
#               ('health_care_and_social_assistance', '244'),
#               ('education_and_training', '64'),
#               ('arts_and_recreation_services', '91')]),
#  OrderedDict([('area_id', '118021350'),
#               ('num_businesses', '1800'),
#               ('retail_trade', '67'),
#               ('accommodation_and_food_services', '77'),
#               ('health_care_and_social_assistance', '101'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '31')]),
#  OrderedDict([('area_id', '118021564'),
#               ('num_businesses', '975'),
#               ('retail_trade', '49'),
#               ('accommodation_and_food_services', '57'),
#               ('health_care_and_social_assistance', '104'),
#               ('education_and_training', '25'),
#               ('arts_and_recreation_services', '29')]),
#  OrderedDict([('area_id', '118021565'),
#               ('num_businesses', '1170'),
#               ('retail_trade', '78'),
#               ('accommodation_and_food_services', '89'),
#               ('health_care_and_social_assistance', '124'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '25')]),
#  OrderedDict([('area_id', '118021566'),
#               ('num_businesses', '1165'),
#               ('retail_trade', '53'),
#               ('accommodation_and_food_services', '27'),
#               ('health_care_and_social_assistance', '130'),
#               ('education_and_training', '11'),
#               ('arts_and_recreation_services', '19')]),
#  OrderedDict([('area_id', '118021567'),
#               ('num_businesses', '945'),
#               ('retail_trade', '52'),
#               ('accommodation_and_food_services', '42'),
#               ('health_care_and_social_assistance', '79'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '26')]),
#  OrderedDict([('area_id', '118021568'),
#               ('num_businesses', '882'),
#               ('retail_trade', '41'),
#               ('accommodation_and_food_services', '64'),
#               ('health_care_and_social_assistance', '69'),
#               ('education_and_training', '18'),
#               ('arts_and_recreation_services', '14')]),
#  OrderedDict([('area_id', '118021569'),
#               ('num_businesses', '1638'),
#               ('retail_trade', '64'),
#               ('accommodation_and_food_services', '49'),
#               ('health_care_and_social_assistance', '143'),
#               ('education_and_training', '32'),
#               ('arts_and_recreation_services', '38')]),
#  OrderedDict([('area_id', '118021570'),
#               ('num_businesses', '1402'),
#               ('retail_trade', '72'),
#               ('accommodation_and_food_services', '86'),
#               ('health_care_and_social_assistance', '269'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '32')]),
#  OrderedDict([('area_id', '119011354'),
#               ('num_businesses', '1472'),
#               ('retail_trade', '108'),
#               ('accommodation_and_food_services', '75'),
#               ('health_care_and_social_assistance', '68'),
#               ('education_and_training', '18'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '119011355'),
#               ('num_businesses', '465'),
#               ('retail_trade', '58'),
#               ('accommodation_and_food_services', '10'),
#               ('health_care_and_social_assistance', '4'),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '119011356'),
#               ('num_businesses', '2202'),
#               ('retail_trade', '174'),
#               ('accommodation_and_food_services', '52'),
#               ('health_care_and_social_assistance', '51'),
#               ('education_and_training', '17'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '119011357'),
#               ('num_businesses', '2495'),
#               ('retail_trade', '183'),
#               ('accommodation_and_food_services', '77'),
#               ('health_care_and_social_assistance', '122'),
#               ('education_and_training', '20'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '119011358'),
#               ('num_businesses', '1495'),
#               ('retail_trade', '95'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '66'),
#               ('education_and_training', '20'),
#               ('arts_and_recreation_services', '14')]),
#  OrderedDict([('area_id', '119011359'),
#               ('num_businesses', '1674'),
#               ('retail_trade', '82'),
#               ('accommodation_and_food_services', '57'),
#               ('health_care_and_social_assistance', '91'),
#               ('education_and_training', '18'),
#               ('arts_and_recreation_services', '25')]),
#  OrderedDict([('area_id', '119011360'),
#               ('num_businesses', '1051'),
#               ('retail_trade', '75'),
#               ('accommodation_and_food_services', '30'),
#               ('health_care_and_social_assistance', '68'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '14')]),
#  OrderedDict([('area_id', '119011361'),
#               ('num_businesses', '1419'),
#               ('retail_trade', '115'),
#               ('accommodation_and_food_services', '40'),
#               ('health_care_and_social_assistance', '63'),
#               ('education_and_training', '19'),
#               ('arts_and_recreation_services', '5')]),
#  OrderedDict([('area_id', '119011571'),
#               ('num_businesses', '1819'),
#               ('retail_trade', '118'),
#               ('accommodation_and_food_services', '57'),
#               ('health_care_and_social_assistance', '167'),
#               ('education_and_training', '30'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '119011572'),
#               ('num_businesses', '1991'),
#               ('retail_trade', '159'),
#               ('accommodation_and_food_services', '76'),
#               ('health_care_and_social_assistance', '103'),
#               ('education_and_training', '21'),
#               ('arts_and_recreation_services', '10')]),
#  OrderedDict([('area_id', '119021362'),
#               ('num_businesses', '1756'),
#               ('retail_trade', '126'),
#               ('accommodation_and_food_services', '74'),
#               ('health_care_and_social_assistance', '63'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '22')]),
#  OrderedDict([('area_id', '119021363'),
#               ('num_businesses', '3094'),
#               ('retail_trade', '229'),
#               ('accommodation_and_food_services', '131'),
#               ('health_care_and_social_assistance', '170'),
#               ('education_and_training', '29'),
#               ('arts_and_recreation_services', '13')]),
#  OrderedDict([('area_id', '119021364'),
#               ('num_businesses', '2677'),
#               ('retail_trade', '152'),
#               ('accommodation_and_food_services', '90'),
#               ('health_care_and_social_assistance', '117'),
#               ('education_and_training', '33'),
#               ('arts_and_recreation_services', '36')]),
#  OrderedDict([('area_id', '119021366'),
#               ('num_businesses', '2171'),
#               ('retail_trade', '140'),
#               ('accommodation_and_food_services', '63'),
#               ('health_care_and_social_assistance', '73'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '7')]),
#  OrderedDict([('area_id', '119021367'),
#               ('num_businesses', '1167'),
#               ('retail_trade', '86'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '28'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '13')]),
#  OrderedDict([('area_id', '119021573'),
#               ('num_businesses', '1742'),
#               ('retail_trade', '99'),
#               ('accommodation_and_food_services', '49'),
#               ('health_care_and_social_assistance', '82'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '119021574'),
#               ('num_businesses', '910'),
#               ('retail_trade', '53'),
#               ('accommodation_and_food_services', '11'),
#               ('health_care_and_social_assistance', '32'),
#               ('education_and_training', '7'),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '119031368'),
#               ('num_businesses', '2992'),
#               ('retail_trade', '264'),
#               ('accommodation_and_food_services', '170'),
#               ('health_care_and_social_assistance', '201'),
#               ('education_and_training', '39'),
#               ('arts_and_recreation_services', '13')]),
#  OrderedDict([('area_id', '119031369'),
#               ('num_businesses', '1719'),
#               ('retail_trade', '101'),
#               ('accommodation_and_food_services', '87'),
#               ('health_care_and_social_assistance', '123'),
#               ('education_and_training', '21'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '119031370'),
#               ('num_businesses', '1049'),
#               ('retail_trade', '75'),
#               ('accommodation_and_food_services', '62'),
#               ('health_care_and_social_assistance', '65'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '10')]),
#  OrderedDict([('area_id', '119031371'),
#               ('num_businesses', '1139'),
#               ('retail_trade', '72'),
#               ('accommodation_and_food_services', '34'),
#               ('health_care_and_social_assistance', '88'),
#               ('education_and_training', '21'),
#               ('arts_and_recreation_services', '14')]),
#  OrderedDict([('area_id', '119031372'),
#               ('num_businesses', '2180'),
#               ('retail_trade', '118'),
#               ('accommodation_and_food_services', '49'),
#               ('health_care_and_social_assistance', '74'),
#               ('education_and_training', '21'),
#               ('arts_and_recreation_services', '20')]),
#  OrderedDict([('area_id', '119031373'),
#               ('num_businesses', '640'),
#               ('retail_trade', '45'),
#               ('accommodation_and_food_services', '48'),
#               ('health_care_and_social_assistance', '37'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '119031374'),
#               ('num_businesses', '2626'),
#               ('retail_trade', '128'),
#               ('accommodation_and_food_services', '98'),
#               ('health_care_and_social_assistance', '208'),
#               ('education_and_training', '25'),
#               ('arts_and_recreation_services', '20')]),
#  OrderedDict([('area_id', '119041375'),
#               ('num_businesses', '1806'),
#               ('retail_trade', '119'),
#               ('accommodation_and_food_services', '78'),
#               ('health_care_and_social_assistance', '68'),
#               ('education_and_training', '23'),
#               ('arts_and_recreation_services', '16')]),
#  OrderedDict([('area_id', '119041376'),
#               ('num_businesses', '2132'),
#               ('retail_trade', '131'),
#               ('accommodation_and_food_services', '66'),
#               ('health_care_and_social_assistance', '107'),
#               ('education_and_training', '23'),
#               ('arts_and_recreation_services', '19')]),
#  OrderedDict([('area_id', '119041377'),
#               ('num_businesses', '1211'),
#               ('retail_trade', '84'),
#               ('accommodation_and_food_services', '67'),
#               ('health_care_and_social_assistance', '84'),
#               ('education_and_training', '17'),
#               ('arts_and_recreation_services', '17')]),
#  OrderedDict([('area_id', '119041378'),
#               ('num_businesses', '1460'),
#               ('retail_trade', '80'),
#               ('accommodation_and_food_services', '67'),
#               ('health_care_and_social_assistance', '233'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '15')]),
#  OrderedDict([('area_id', '119041379'),
#               ('num_businesses', '1517'),
#               ('retail_trade', '71'),
#               ('accommodation_and_food_services', '60'),
#               ('health_care_and_social_assistance', '75'),
#               ('education_and_training', '25'),
#               ('arts_and_recreation_services', '21')]),
#  OrderedDict([('area_id', '119041380'),
#               ('num_businesses', '1363'),
#               ('retail_trade', '74'),
#               ('accommodation_and_food_services', '64'),
#               ('health_care_and_social_assistance', '73'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '13')]),
#  OrderedDict([('area_id', '119041381'),
#               ('num_businesses', '2093'),
#               ('retail_trade', '177'),
#               ('accommodation_and_food_services', '108'),
#               ('health_care_and_social_assistance', '84'),
#               ('education_and_training', '21'),
#               ('arts_and_recreation_services', '22')]),
#  OrderedDict([('area_id', '119041382'),
#               ('num_businesses', '1642'),
#               ('retail_trade', '99'),
#               ('accommodation_and_food_services', '93'),
#               ('health_care_and_social_assistance', '91'),
#               ('education_and_training', '28'),
#               ('arts_and_recreation_services', '26')]),
#  OrderedDict([('area_id', '120011383'),
#               ('num_businesses', '2597'),
#               ('retail_trade', '131'),
#               ('accommodation_and_food_services', '113'),
#               ('health_care_and_social_assistance', '226'),
#               ('education_and_training', '49'),
#               ('arts_and_recreation_services', '29')]),
#  OrderedDict([('area_id', '120011384'),
#               ('num_businesses', '2809'),
#               ('retail_trade', '159'),
#               ('accommodation_and_food_services', '196'),
#               ('health_care_and_social_assistance', '178'),
#               ('education_and_training', '40'),
#               ('arts_and_recreation_services', '25')]),
#  OrderedDict([('area_id', '120011385'),
#               ('num_businesses', '2357'),
#               ('retail_trade', '149'),
#               ('accommodation_and_food_services', '104'),
#               ('health_care_and_social_assistance', '217'),
#               ('education_and_training', '31'),
#               ('arts_and_recreation_services', '36')]),
#  OrderedDict([('area_id', '120011386'),
#               ('num_businesses', '2635'),
#               ('retail_trade', '166'),
#               ('accommodation_and_food_services', '106'),
#               ('health_care_and_social_assistance', '225'),
#               ('education_and_training', '41'),
#               ('arts_and_recreation_services', '36')]),
#  OrderedDict([('area_id', '120021387'),
#               ('num_businesses', '2372'),
#               ('retail_trade', '99'),
#               ('accommodation_and_food_services', '103'),
#               ('health_care_and_social_assistance', '232'),
#               ('education_and_training', '37'),
#               ('arts_and_recreation_services', '80')]),
#  OrderedDict([('area_id', '120021388'),
#               ('num_businesses', '3345'),
#               ('retail_trade', '218'),
#               ('accommodation_and_food_services', '169'),
#               ('health_care_and_social_assistance', '300'),
#               ('education_and_training', '59'),
#               ('arts_and_recreation_services', '144')]),
#  OrderedDict([('area_id', '120021389'),
# ...
#               ('arts_and_recreation_services', '10')]),
#  OrderedDict([('area_id', '126021591'),
#               ('num_businesses', '2301'),
#               ('retail_trade', '146'),
#               ('accommodation_and_food_services', '113'),
#               ('health_care_and_social_assistance', '134'),
#               ('education_and_training', '37'),
#               ('arts_and_recreation_services', '28')]),
#  OrderedDict([('area_id', '127011504'),
#               ('num_businesses', '508'),
#               ('retail_trade', '25'),
#               ('accommodation_and_food_services', '24'),
#               ('health_care_and_social_assistance', '37'),
#               ('education_and_training', '4'),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '127011505'),
#               ('num_businesses', '1414'),
#               ('retail_trade', '54'),
#               ('accommodation_and_food_services', '25'),
#               ('health_care_and_social_assistance', '34'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '127011506'),
#               ('num_businesses', '1555'),
#               ('retail_trade', '63'),
#               ('accommodation_and_food_services', '23'),
#               ('health_care_and_social_assistance', '35'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '22')]),
#  OrderedDict([('area_id', '127011592'),
#               ('num_businesses', '12'),
#               ('retail_trade', ''),
#               ('accommodation_and_food_services', ''),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '127011593'),
#               ('num_businesses', '586'),
#               ('retail_trade', '30'),
#               ('accommodation_and_food_services', '21'),
#               ('health_care_and_social_assistance', '31'),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '127011594'),
#               ('num_businesses', '722'),
#               ('retail_trade', '57'),
#               ('accommodation_and_food_services', '28'),
#               ('health_care_and_social_assistance', '46'),
#               ('education_and_training', '7'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '127011595'),
#               ('num_businesses', '672'),
#               ('retail_trade', '25'),
#               ('accommodation_and_food_services', '22'),
#               ('health_care_and_social_assistance', '25'),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '5')]),
#  OrderedDict([('area_id', '127011596'),
#               ('num_businesses', '633'),
#               ('retail_trade', '27'),
#               ('accommodation_and_food_services', '26'),
#               ('health_care_and_social_assistance', '35'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '127011597'),
#               ('num_businesses', '1021'),
#               ('retail_trade', '55'),
#               ('accommodation_and_food_services', '19'),
#               ('health_care_and_social_assistance', '44'),
#               ('education_and_training', '9'),
#               ('arts_and_recreation_services', '7')]),
#  OrderedDict([('area_id', '127021509'),
#               ('num_businesses', '852'),
#               ('retail_trade', '66'),
#               ('accommodation_and_food_services', '31'),
#               ('health_care_and_social_assistance', '40'),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '127021510'),
#               ('num_businesses', '1364'),
#               ('retail_trade', '64'),
#               ('accommodation_and_food_services', '35'),
#               ('health_care_and_social_assistance', '66'),
#               ('education_and_training', '26'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '127021511'),
#               ('num_businesses', '1872'),
#               ('retail_trade', '262'),
#               ('accommodation_and_food_services', '118'),
#               ('health_care_and_social_assistance', '153'),
#               ('education_and_training', '15'),
#               ('arts_and_recreation_services', '8')]),
#  OrderedDict([('area_id', '127021512'),
#               ('num_businesses', '926'),
#               ('retail_trade', '62'),
#               ('accommodation_and_food_services', '41'),
#               ('health_care_and_social_assistance', '54'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '127021513'),
#               ('num_businesses', '1045'),
#               ('retail_trade', '88'),
#               ('accommodation_and_food_services', '62'),
#               ('health_care_and_social_assistance', '63'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '127021514'),
#               ('num_businesses', '721'),
#               ('retail_trade', '41'),
#               ('accommodation_and_food_services', '34'),
#               ('health_care_and_social_assistance', '28'),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '7')]),
#  OrderedDict([('area_id', '127021515'),
#               ('num_businesses', '1364'),
#               ('retail_trade', '142'),
#               ('accommodation_and_food_services', '64'),
#               ('health_care_and_social_assistance', '111'),
#               ('education_and_training', '12'),
#               ('arts_and_recreation_services', '5')]),
#  OrderedDict([('area_id', '127021516'),
#               ('num_businesses', '959'),
#               ('retail_trade', '63'),
#               ('accommodation_and_food_services', '40'),
#               ('health_care_and_social_assistance', '73'),
#               ('education_and_training', '14'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '127021517'),
#               ('num_businesses', '493'),
#               ('retail_trade', '28'),
#               ('accommodation_and_food_services', '27'),
#               ('health_care_and_social_assistance', '21'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '127021518'),
#               ('num_businesses', '963'),
#               ('retail_trade', '49'),
#               ('accommodation_and_food_services', '21'),
#               ('health_care_and_social_assistance', '17'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '5')]),
#  OrderedDict([('area_id', '127021519'),
#               ('num_businesses', '1393'),
#               ('retail_trade', '89'),
#               ('accommodation_and_food_services', '44'),
#               ('health_care_and_social_assistance', '54'),
#               ('education_and_training', '16'),
#               ('arts_and_recreation_services', '12')]),
#  OrderedDict([('area_id', '127021520'),
#               ('num_businesses', '624'),
#               ('retail_trade', '40'),
#               ('accommodation_and_food_services', '26'),
#               ('health_care_and_social_assistance', '24'),
#               ('education_and_training', '3'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '127021521'),
#               ('num_businesses', '1693'),
#               ('retail_trade', '97'),
#               ('accommodation_and_food_services', '20'),
#               ('health_care_and_social_assistance', '6'),
#               ('education_and_training', '8'),
#               ('arts_and_recreation_services', '12')]),
#  OrderedDict([('area_id', '127031522'),
#               ('num_businesses', '1092'),
#               ('retail_trade', '85'),
#               ('accommodation_and_food_services', '31'),
#               ('health_care_and_social_assistance', '65'),
#               ('education_and_training', '10'),
#               ('arts_and_recreation_services', '16')]),
#  OrderedDict([('area_id', '127031523'),
#               ('num_businesses', '2431'),
#               ('retail_trade', '170'),
#               ('accommodation_and_food_services', '70'),
#               ('health_care_and_social_assistance', '75'),
#               ('education_and_training', '19'),
#               ('arts_and_recreation_services', '16')]),
#  OrderedDict([('area_id', '127031524'),
#               ('num_businesses', '1148'),
#               ('retail_trade', '57'),
#               ('accommodation_and_food_services', '45'),
#               ('health_care_and_social_assistance', '69'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '127031598'),
#               ('num_businesses', '2589'),
#               ('retail_trade', '206'),
#               ('accommodation_and_food_services', '107'),
#               ('health_care_and_social_assistance', '266'),
#               ('education_and_training', '29'),
#               ('arts_and_recreation_services', '9')]),
#  OrderedDict([('area_id', '127031599'),
#               ('num_businesses', '462'),
#               ('retail_trade', '36'),
#               ('accommodation_and_food_services', '5'),
#               ('health_care_and_social_assistance', '17'),
#               ('education_and_training', '13'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '127031600'),
#               ('num_businesses', '1668'),
#               ('retail_trade', '106'),
#               ('accommodation_and_food_services', '48'),
#               ('health_care_and_social_assistance', '68'),
#               ('education_and_training', '21'),
#               ('arts_and_recreation_services', '14')]),
#  OrderedDict([('area_id', '127031601'),
#               ('num_businesses', '330'),
#               ('retail_trade', '29'),
#               ('accommodation_and_food_services', '3'),
#               ('health_care_and_social_assistance', '9'),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '22')]),
#  OrderedDict([('area_id', '128011529'),
#               ('num_businesses', '1421'),
#               ('retail_trade', '60'),
#               ('accommodation_and_food_services', '41'),
#               ('health_care_and_social_assistance', '73'),
#               ('education_and_training', '24'),
#               ('arts_and_recreation_services', '26')]),
#  OrderedDict([('area_id', '128011530'),
#               ('num_businesses', '2217'),
#               ('retail_trade', '154'),
#               ('accommodation_and_food_services', '78'),
#               ('health_care_and_social_assistance', '209'),
#               ('education_and_training', '26'),
#               ('arts_and_recreation_services', '25')]),
#  OrderedDict([('area_id', '128011531'),
#               ('num_businesses', '2301'),
#               ('retail_trade', '145'),
#               ('accommodation_and_food_services', '96'),
#               ('health_care_and_social_assistance', '90'),
#               ('education_and_training', '17'),
#               ('arts_and_recreation_services', '30')]),
#  OrderedDict([('area_id', '128011602'),
#               ('num_businesses', '2052'),
#               ('retail_trade', '136'),
#               ('accommodation_and_food_services', '82'),
#               ('health_care_and_social_assistance', '91'),
#               ('education_and_training', '22'),
#               ('arts_and_recreation_services', '19')]),
#  OrderedDict([('area_id', '128011603'),
#               ('num_businesses', '1157'),
#               ('retail_trade', '56'),
#               ('accommodation_and_food_services', '23'),
#               ('health_care_and_social_assistance', '67'),
#               ('education_and_training', '19'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '128011604'),
#               ('num_businesses', '2485'),
#               ('retail_trade', '119'),
#               ('accommodation_and_food_services', '130'),
#               ('health_care_and_social_assistance', '109'),
#               ('education_and_training', '42'),
#               ('arts_and_recreation_services', '42')]),
#  OrderedDict([('area_id', '128011605'),
#               ('num_businesses', '442'),
#               ('retail_trade', '9'),
#               ('accommodation_and_food_services', '14'),
#               ('health_care_and_social_assistance', '22'),
#               ('education_and_training', '5'),
#               ('arts_and_recreation_services', '4')]),
#  OrderedDict([('area_id', '128011606'),
#               ('num_businesses', '924'),
#               ('retail_trade', '45'),
#               ('accommodation_and_food_services', '23'),
#               ('health_care_and_social_assistance', '56'),
#               ('education_and_training', '17'),
#               ('arts_and_recreation_services', '15')]),
#  OrderedDict([('area_id', '128021533'),
#               ('num_businesses', '377'),
#               ('retail_trade', '23'),
#               ('accommodation_and_food_services', '8'),
#               ('health_care_and_social_assistance', '12'),
#               ('education_and_training', '13'),
#               ('arts_and_recreation_services', '3')]),
#  OrderedDict([('area_id', '128021534'),
#               ('num_businesses', '1138'),
#               ('retail_trade', '51'),
#               ('accommodation_and_food_services', '26'),
#               ('health_care_and_social_assistance', '76'),
#               ('education_and_training', '12'),
#               ('arts_and_recreation_services', '10')]),
#  OrderedDict([('area_id', '128021535'),
#               ('num_businesses', '1595'),
#               ('retail_trade', '77'),
#               ('accommodation_and_food_services', '46'),
#               ('health_care_and_social_assistance', '92'),
#               ('education_and_training', '39'),
#               ('arts_and_recreation_services', '21')]),
#  OrderedDict([('area_id', '128021536'),
#               ('num_businesses', '1591'),
#               ('retail_trade', '90'),
#               ('accommodation_and_food_services', '49'),
#               ('health_care_and_social_assistance', '84'),
#               ('education_and_training', '24'),
#               ('arts_and_recreation_services', '24')]),
#  OrderedDict([('area_id', '128021537'),
#               ('num_businesses', '3'),
#               ('retail_trade', ''),
#               ('accommodation_and_food_services', '3'),
#               ('health_care_and_social_assistance', ''),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '')]),
#  OrderedDict([('area_id', '128021538'),
#               ('num_businesses', '2086'),
#               ('retail_trade', '107'),
#               ('accommodation_and_food_services', '79'),
#               ('health_care_and_social_assistance', '134'),
#               ('education_and_training', '36'),
#               ('arts_and_recreation_services', '27')]),
#  OrderedDict([('area_id', '128021607'),
#               ('num_businesses', '1121'),
#               ('retail_trade', '75'),
#               ('accommodation_and_food_services', '38'),
#               ('health_care_and_social_assistance', '76'),
#               ('education_and_training', '28'),
#               ('arts_and_recreation_services', '11')]),
#  OrderedDict([('area_id', '128021608'),
#               ('num_businesses', '417'),
#               ('retail_trade', '17'),
#               ('accommodation_and_food_services', '6'),
#               ('health_care_and_social_assistance', '17'),
#               ('education_and_training', '7'),
#               ('arts_and_recreation_services', '7')]),
#  OrderedDict([('area_id', '128021609'),
#               ('num_businesses', '259'),
#               ('retail_trade', '10'),
#               ('accommodation_and_food_services', '5'),
#               ('health_care_and_social_assistance', '10'),
#               ('education_and_training', ''),
#               ('arts_and_recreation_services', '7')])]

# %%
import psycopg2

def pgconnect():
   
    try: 
        conn = psycopg2.connect(host='localhost', database='assignment', user='postgres', password='6688')
        
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return conn

# %%
def pgexec( conn, sqlcmd, args, msg, silent=False ):
   """ utility function to execute some SQL statement
       can take optional arguments to fill in (dictionary)
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
               cur.execute(sqlcmd)
            else:
               cur.execute(sqlcmd, args)
            if silent == False: 
                print("success: " + msg)
            retval = True
         except Exception as e:
            if silent == False: 
                print("db error: ")
                print(e)
   return retval

# 1st: login to database
conn = pgconnect()

# if you want to reset the table
pgexec (conn, "DROP TABLE IF EXISTS Neighbourhoods", None, "Reset Table Neighbourhoods")
pgexec (conn, "DROP TABLE IF EXISTS BusinessStats", None, "Reset Table BusinessStats")

# 2nd: ensure that the schema is in place

neighbourhoods_schema = """CREATE TABLE IF NOT EXISTS Neighbourhoods (
                         area_id BIGINT PRIMARY KEY,
                         area_name VARCHAR(150),
                         land_area FLOAT,
                         population INT,
                         number_of_dwellings INT,
                         number_of_businesses INT,
                         NE_lat FLOAT,
                         NE_lng FLOAT,
                         SW_lat FLOAT,
                         SW_lng FLOAT
                       )
                       CREATE TABLE IF NOT EXISTS BusinessStats(
                             area_id BIGINT PRIMARY KEY,
                             num_businesses INT,
                             retail_trade INT，
                             accommodation_and_food_services INT,
                             health_care_and_social_assistance INT,
                             education_and_training INT,
                             arts_and_recreation_services INT
                           )
                       select *   FROM Neighbourhoods natural join  BusinessStats; 
                   """
pgexec (conn, neighbourhoods_schema, None, "Create Table Neighbourhoods")
pgexec (conn, neighbourhoods_schema, None, "Create Table BusinessStats")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
 #insert_stmt = """INSERT INTO Neighbourhoods(area_id, area_name, land_area, population, number_of_dwellings, number_of_businesses) VALUES (%(area_id)s, %(area_name)s, %(parent_area_id)s)"""
# for row in data_organisations:
 #   pgexec (conn, insert_stmt, row, "row inserted")
# Out:
# connected
# success: Reset Table Neighbourhoods
# success: Reset Table BusinessStats
# db error:
# 错误:  语法错误 在 "CREATE" 或附近的
# LINE 13:                        CREATE TABLE IF NOT EXISTS BusinessSt...
#                                 ^
#
# db error:
# 错误:  语法错误 在 "CREATE" 或附近的
# LINE 13:                        CREATE TABLE IF NOT EXISTS BusinessSt...
#                                 ^
# False

# %%
import numpy as np
DEFAULT_VALUE = 0

def clean(data, column_key, convert_function, default_value):
    special_values= {' ' :  0} 
    for row in data:
        old_value = row[column_key]
        new_value = default_value
        try:
            if old_value in special_values.keys():
                new_value = special_values[old_value]
            else:
                new_value = convert_function(old_value)
        except (ValueError, TypeError):
            print('Replacing {} with {} in column {}'.format(row[column_key], new_value, column_key))
        row[column_key] = new_value

# %%
# data cleaning

clean(data_Neighbourhoods, 'number_of_businesses', int, DEFAULT_VALUE)

# %%
data_Neighbourhoods
# Out:
# [OrderedDict([('area_id', '102011028'),
#               ('area_name', 'Avoca Beach - Copacabana'),
#               ('land_area', '643.8'),
#               ('population', '7590'),
#               ('number_of_dwellings', '2325'),
#               ('number_of_businesses', 738)]),
#  OrderedDict([('area_id', '102011029'),
#               ('area_name', 'Box Head - MacMasters Beach'),
#               ('land_area', '3208.6'),
#               ('population', '10986'),
#               ('number_of_dwellings', '3847'),
#               ('number_of_businesses', 907)]),
#  OrderedDict([('area_id', '102011030'),
#               ('area_name', 'Calga - Kulnura'),
#               ('land_area', '76795.1'),
#               ('population', '4841'),
#               ('number_of_dwellings', '1575'),
#               ('number_of_businesses', 1102)]),
#  OrderedDict([('area_id', '102011031'),
#               ('area_name', 'Erina - Green Point'),
#               ('land_area', '3379.3'),
#               ('population', '14237'),
#               ('number_of_dwellings', '4450'),
#               ('number_of_businesses', 1666)]),
#  OrderedDict([('area_id', '102011032'),
#               ('area_name', 'Gosford - Springfield'),
#               ('land_area', '1691.2'),
#               ('population', '19385'),
#               ('number_of_dwellings', '6373'),
#               ('number_of_businesses', 2126)]),
#  OrderedDict([('area_id', '102011033'),
#               ('area_name', 'Kariong'),
#               ('land_area', '830.6'),
#               ('population', '6540'),
#               ('number_of_dwellings', '1824'),
#               ('number_of_businesses', 352)]),
#  OrderedDict([('area_id', '102011034'),
#               ('area_name', 'Kincumber - Picketts Valley'),
#               ('land_area', '1208.9'),
#               ('population', '7428'),
#               ('number_of_dwellings', '1946'),
#               ('number_of_businesses', 479)]),
#  OrderedDict([('area_id', '102011035'),
#               ('area_name', 'Narara'),
#               ('land_area', '770.2'),
#               ('population', '6853'),
#               ('number_of_dwellings', '2006'),
#               ('number_of_businesses', 292)]),
#  OrderedDict([('area_id', '102011036'),
#               ('area_name', 'Niagara Park - Lisarow'),
#               ('land_area', '1673.2'),
#               ('population', '8173'),
#               ('number_of_dwellings', '2345'),
#               ('number_of_businesses', 477)]),
#  OrderedDict([('area_id', '102011037'),
#               ('area_name', 'Point Clare - Koolewong'),
#               ('land_area', '678.7'),
#               ('population', '6281'),
#               ('number_of_dwellings', '2220'),
#               ('number_of_businesses', 312)]),
#  OrderedDict([('area_id', '102011038'),
#               ('area_name', 'Saratoga - Davistown'),
#               ('land_area', '476.8'),
#               ('population', '7177'),
#               ('number_of_dwellings', '2366'),
#               ('number_of_businesses', 486)]),
#  OrderedDict([('area_id', '102011039'),
#               ('area_name', 'Terrigal - North Avoca'),
#               ('land_area', '1010.7'),
#               ('population', '14048'),
#               ('number_of_dwellings', '4457'),
#               ('number_of_businesses', 1351)]),
#  OrderedDict([('area_id', '102011040'),
#               ('area_name', 'Umina - Booker Bay - Patonga'),
#               ('land_area', '2522.8'),
#               ('population', '24251'),
#               ('number_of_dwellings', '7540'),
#               ('number_of_businesses', 1217)]),
#  OrderedDict([('area_id', '102011041'),
#               ('area_name', 'Wamberal - Forresters Beach'),
#               ('land_area', '1372.2'),
#               ('population', '10308'),
#               ('number_of_dwellings', '2947'),
#               ('number_of_businesses', 924)]),
#  OrderedDict([('area_id', '102011042'),
#               ('area_name', 'Woy Woy - Blackwall'),
#               ('land_area', '1742.3'),
#               ('population', '14327'),
#               ('number_of_dwellings', '4304'),
#               ('number_of_businesses', 691)]),
#  OrderedDict([('area_id', '102011043'),
#               ('area_name', 'Wyoming'),
#               ('land_area', '838.1'),
#               ('population', '11659'),
#               ('number_of_dwellings', '3269'),
#               ('number_of_businesses', 486)]),
#  OrderedDict([('area_id', '102021044'),
#               ('area_name', 'Bateau Bay - Killarney Vale'),
#               ('land_area', '1086'),
#               ('population', '22465'),
#               ('number_of_dwellings', '6941'),
#               ('number_of_businesses', 1035)]),
#  OrderedDict([('area_id', '102021045'),
#               ('area_name', 'Blue Haven - San Remo'),
#               ('land_area', '2098'),
#               ('population', '11366'),
#               ('number_of_dwellings', '3624'),
#               ('number_of_businesses', 290)]),
#  OrderedDict([('area_id', '102021046'),
#               ('area_name', 'Budgewoi - Buff Point - Halekulani'),
#               ('land_area', '935.3'),
#               ('population', '9639'),
#               ('number_of_dwellings', '3648'),
#               ('number_of_businesses', 350)]),
#  OrderedDict([('area_id', '102021047'),
#               ('area_name', 'Chittaway Bay - Tumbi Umbi'),
#               ('land_area', '2449.9'),
#               ('population', '15697'),
#               ('number_of_dwellings', '4947'),
#               ('number_of_businesses', 994)]),
#  OrderedDict([('area_id', '102021048'),
#               ('area_name', 'Gorokan - Kanwal - Charmhaven'),
#               ('land_area', '1124.9'),
#               ('population', '22567'),
#               ('number_of_dwellings', '7562'),
#               ('number_of_businesses', 816)]),
#  OrderedDict([('area_id', '102021049'),
#               ('area_name', 'Jilliby - Yarramalong'),
#               ('land_area', '34676.6'),
#               ('population', '3520'),
#               ('number_of_dwellings', '973'),
#               ('number_of_businesses', 390)]),
#  OrderedDict([('area_id', '102021050'),
#               ('area_name', 'Lake Munmorah - Mannering Park'),
#               ('land_area', '3549.5'),
#               ('population', '11093'),
#               ('number_of_dwellings', '4252'),
#               ('number_of_businesses', 424)]),
#  OrderedDict([('area_id', '102021051'),
#               ('area_name', 'Ourimbah - Fountaindale'),
#               ('land_area', '11411.7'),
#               ('population', '4996'),
#               ('number_of_dwellings', '1317'),
#               ('number_of_businesses', 439)]),
#  OrderedDict([('area_id', '102021052'),
#               ('area_name', 'Summerland Point - Gwandalan'),
#               ('land_area', '917.9'),
#               ('population', '5904'),
#               ('number_of_dwellings', '2143'),
#               ('number_of_businesses', 287)]),
#  OrderedDict([('area_id', '102021053'),
#               ('area_name', 'The Entrance'),
#               ('land_area', '1385.8'),
#               ('population', '15416'),
#               ('number_of_dwellings', '4428'),
#               ('number_of_businesses', 1000)]),
#  OrderedDict([('area_id', '102021054'),
#               ('area_name', 'Toukley - Norah Head'),
#               ('land_area', '1052.2'),
#               ('population', '10092'),
#               ('number_of_dwellings', '3208'),
#               ('number_of_businesses', 588)]),
#  OrderedDict([('area_id', '102021055'),
#               ('area_name', 'Tuggerah - Kangy Angy'),
#               ('land_area', '2784.6'),
#               ('population', '5480'),
#               ('number_of_dwellings', '1420'),
#               ('number_of_businesses', 973)]),
#  OrderedDict([('area_id', '102021056'),
#               ('area_name', 'Warnervale - Wadalba'),
#               ('land_area', '4289'),
#               ('population', '16365'),
#               ('number_of_dwellings', '4387'),
#               ('number_of_businesses', 768)]),
#  OrderedDict([('area_id', '102021057'),
#               ('area_name', 'Wyong'),
#               ('land_area', '1503.3'),
#               ('population', '9114'),
#               ('number_of_dwellings', '2805'),
#               ('number_of_businesses', 645)]),
#  OrderedDict([('area_id', '115011290'),
#               ('area_name', 'Baulkham Hills (East)'),
#               ('land_area', '830.8'),
#               ('population', '24370'),
#               ('number_of_dwellings', '6258'),
#               ('number_of_businesses', 1880)]),
#  OrderedDict([('area_id', '115011291'),
#               ('area_name', 'Baulkham Hills (West) - Bella Vista'),
#               ('land_area', '1096.3'),
#               ('population', '21416'),
#               ('number_of_dwellings', '5244'),
#               ('number_of_businesses', 4674)]),
#  OrderedDict([('area_id', '115011294'),
#               ('area_name', 'Glenhaven'),
#               ('land_area', '723.1'),
#               ('population', '6467'),
#               ('number_of_dwellings', '1687'),
#               ('number_of_businesses', 736)]),
#  OrderedDict([('area_id', '115011296'),
#               ('area_name', 'West Pennant Hills'),
#               ('land_area', '782.9'),
#               ('population', '13244'),
#               ('number_of_dwellings', '3543'),
#               ('number_of_businesses', 1503)]),
#  OrderedDict([('area_id', '115011553'),
#               ('area_name', 'Castle Hill - Central'),
#               ('land_area', '415.1'),
#               ('population', '7992'),
#               ('number_of_dwellings', '2236'),
#               ('number_of_businesses', 1803)]),
#  OrderedDict([('area_id', '115011554'),
#               ('area_name', 'Castle Hill - East'),
#               ('land_area', '207.2'),
#               ('population', '5685'),
#               ('number_of_dwellings', '1489'),
#               ('number_of_businesses', 389)]),
#  OrderedDict([('area_id', '115011555'),
#               ('area_name', 'Castle Hill - North'),
#               ('land_area', '681.5'),
#               ('population', '12409'),
#               ('number_of_dwellings', '3296'),
#               ('number_of_businesses', 1347)]),
#  OrderedDict([('area_id', '115011556'),
#               ('area_name', 'Castle Hill - South'),
#               ('land_area', '412.8'),
#               ('population', '9970'),
#               ('number_of_dwellings', '2774'),
#               ('number_of_businesses', 1169)]),
#  OrderedDict([('area_id', '115011557'),
#               ('area_name', 'Castle Hill - West'),
#               ('land_area', '163.6'),
#               ('population', '5368'),
#               ('number_of_dwellings', '1315'),
#               ('number_of_businesses', 520)]),
#  OrderedDict([('area_id', '115011558'),
#               ('area_name', 'Cherrybrook'),
#               ('land_area', '825.1'),
#               ('population', '19518'),
#               ('number_of_dwellings', '4862'),
#               ('number_of_businesses', 1526)]),
#  OrderedDict([('area_id', '115011559'),
#               ('area_name', 'Kellyville'),
#               ('land_area', '1064.1'),
#               ('population', '25111'),
#               ('number_of_dwellings', '6122'),
#               ('number_of_businesses', 1856)]),
#  OrderedDict([('area_id', '115021297'),
#               ('area_name', 'Dural - Kenthurst - Wisemans Ferry'),
#               ('land_area', '37754'),
#               ('population', '22060'),
#               ('number_of_dwellings', '5920'),
#               ('number_of_businesses', 3683)]),
#  OrderedDict([('area_id', '115021298'),
#               ('area_name', 'Galston - Laughtondale'),
#               ('land_area', '19169.9'),
#               ('population', '5378'),
#               ('number_of_dwellings', '1569'),
#               ('number_of_businesses', 816)]),
#  OrderedDict([('area_id', '115031299'),
#               ('area_name', 'Bilpin - Colo - St Albans'),
#               ('land_area', '216016'),
#               ('population', '2751'),
#               ('number_of_dwellings', '858'),
#               ('number_of_businesses', 325)]),
#  OrderedDict([('area_id', '115031300'),
#               ('area_name', 'Kurrajong Heights - Ebenezer'),
#               ('land_area', '33185'),
#               ('population', '22443'),
#               ('number_of_dwellings', '6680'),
#               ('number_of_businesses', 2430)]),
#  OrderedDict([('area_id', '115041301'),
#               ('area_name', 'Pitt Town - McGraths Hill'),
#               ('land_area', '8155.2'),
#               ('population', '11034'),
#               ('number_of_dwellings', '3083'),
#               ('number_of_businesses', 1622)]),
#  OrderedDict([('area_id', '115041302'),
#               ('area_name', 'Rouse Hill - Beaumont Hills'),
#               ('land_area', '3667.3'),
#               ('population', '24977'),
#               ('number_of_dwellings', '5400'),
#               ('number_of_businesses', 2154)]),
#  OrderedDict([('area_id', '116011303'),
#               ('area_name', 'Blacktown (East) - Kings Park'),
#               ('land_area', '797.5'),
#               ('population', '17868'),
#               ('number_of_dwellings', '5044'),
#               ('number_of_businesses', 2319)]),
#  OrderedDict([('area_id', '116011304'),
#               ('area_name', 'Blacktown (North) - Marayong'),
#               ('land_area', '738.3'),
#               ('population', '18984'),
#               ('number_of_dwellings', '4913'),
#               ('number_of_businesses', 867)]),
#  OrderedDict([('area_id', '116011306'),
#               ('area_name', 'Doonside - Woodcroft'),
#               ('land_area', '991.1'),
#               ('population', '24242'),
#               ('number_of_dwellings', '5920'),
#               ('number_of_businesses', 978)]),
#  OrderedDict([('area_id', '116011307'),
#               ('area_name', 'Lalor Park - Kings Langley'),
#               ('land_area', '1180'),
#               ('population', '25825'),
#               ('number_of_dwellings', '7955'),
#               ('number_of_businesses', 2401)]),
#  OrderedDict([('area_id', '116011308'),
#               ('area_name', 'Seven Hills - Toongabbie'),
#               ('land_area', '1120.3'),
#               ('population', '25379'),
#               ('number_of_dwellings', '6182'),
#               ('number_of_businesses', 1616)]),
#  OrderedDict([('area_id', '116011560'),
#               ('area_name', 'Blacktown (South)'),
#               ('land_area', '335.9'),
#               ('population', '12939'),
#               ('number_of_dwellings', '2840'),
#               ('number_of_businesses', 723)]),
#  OrderedDict([('area_id', '116011561'),
#               ('area_name', 'Blacktown (West)'),
#               ('land_area', '467.5'),
#               ('population', '16829'),
#               ('number_of_dwellings', '4165'),
#               ('number_of_businesses', 830)]),
#  OrderedDict([('area_id', '116021309'),
#               ('area_name', 'Glenwood'),
#               ('land_area', '511.9'),
#               ('population', '16739'),
#               ('number_of_dwellings', '4282'),
#               ('number_of_businesses', 1236)]),
#  OrderedDict([('area_id', '116021310'),
#               ('area_name', 'Parklea - Kellyville Ridge'),
#               ('land_area', '981.3'),
#               ('population', '34440'),
#               ('number_of_dwellings', '7498'),
#               ('number_of_businesses', 2116)]),
#  OrderedDict([('area_id', '116021312'),
#               ('area_name', 'Riverstone - Marsden Park'),
#               ('land_area', '7942.1'),
#               ('population', '21668'),
#               ('number_of_dwellings', '4867'),
#               ('number_of_businesses', 1573)]),
#  OrderedDict([('area_id', '116021562'),
#               ('area_name', 'Acacia Gardens'),
#               ('land_area', '94.7'),
#               ('population', '3905'),
#               ('number_of_dwellings', '272'),
#               ('number_of_businesses', 257)]),
#  OrderedDict([('area_id', '116021563'),
#               ('area_name', 'Quakers Hill'),
#               ('land_area', '776.8'),
#               ('population', '23972'),
#               ('number_of_dwellings', '2761'),
#               ('number_of_businesses', 1246)]),
#  OrderedDict([('area_id', '116031313'),
#               ('area_name', 'Bidwill - Hebersham - Emerton'),
#               ('land_area', '609.5'),
#               ('population', '18942'),
#               ('number_of_dwellings', '4746'),
#               ('number_of_businesses', 424)]),
#  OrderedDict([('area_id', '116031314'),
#               ('area_name', 'Glendenning - Dean Park'),
#               ('land_area', '514.3'),
#               ('population', '8659'),
#               ('number_of_dwellings', '2300'),
#               ('number_of_businesses', 600)]),
#  OrderedDict([('area_id', '116031315'),
#               ('area_name', 'Hassall Grove - Plumpton'),
#               ('land_area', '620.5'),
#               ('population', '21429'),
#               ('number_of_dwellings', '5072'),
#               ('number_of_businesses', 921)]),
#  OrderedDict([('area_id', '116031316'),
#               ('area_name', 'Lethbridge Park - Tregear'),
#               ('land_area', '1126.7'),
#               ('population', '21997'),
#               ('number_of_dwellings', '5899'),
#               ('number_of_businesses', 435)]),
#  OrderedDict([('area_id', '116031317'),
#               ('area_name', 'Mount Druitt - Whalan'),
#               ('land_area', '868.6'),
#               ('population', '23616'),
#               ('number_of_dwellings', '5253'),
#               ('number_of_businesses', 1136)]),
#  OrderedDict([('area_id', '116031318'),
#               ('area_name', 'Prospect Reservoir'),
#               ('land_area', '3069.2'),
#               ('population', '40'),
#               ('number_of_dwellings', '5'),
#               ('number_of_businesses', 500)]),
#  OrderedDict([('area_id', '116031319'),
#               ('area_name', 'Rooty Hill - Minchinbury'),
#               ('land_area', '1462.4'),
#               ('population', '21912'),
#               ('number_of_dwellings', '5062'),
#               ('number_of_businesses', 1194)]),
#  OrderedDict([('area_id', '117011320'),
#               ('area_name', 'Banksmeadow'),
#               ('land_area', '336.8'),
#               ('population', '21'),
#               ('number_of_dwellings', '0'),
#               ('number_of_businesses', 409)]),
#  OrderedDict([('area_id', '117011321'),
#               ('area_name', 'Botany'),
#               ('land_area', '343.1'),
#               ('population', '11679'),
#               ('number_of_dwellings', '2676'),
#               ('number_of_businesses', 1304)]),
#  OrderedDict([('area_id', '117011322'),
#               ('area_name', 'Mascot - Eastlakes'),
#               ('land_area', '616.5'),
#               ('population', '27068'),
#               ('number_of_dwellings', '8150'),
#               ('number_of_businesses', 2580)]),
#  OrderedDict([('area_id', '117011323'),
#               ('area_name', 'Pagewood - Hillsdale - Daceyville'),
#               ('land_area', '311.9'),
#               ('population', '12097'),
#               ('number_of_dwellings', '3340'),
#               ('number_of_businesses', 911)]),
#  OrderedDict([('area_id', '117011324'),
#               ('area_name', 'Port Botany Industrial'),
#               ('land_area', '280.4'),
#               ('population', '7'),
#               ('number_of_dwellings', '0'),
#               ('number_of_businesses', 135)]),
#  OrderedDict([('area_id', '117011325'),
#               ('area_name', 'Sydney Airport'),
#               ('land_area', '891.1'),
#               ('population', '202'),
#               ('number_of_dwellings', '0'),
#               ('number_of_businesses', 9)]),
#  OrderedDict([('area_id', '117021326'),
#               ('area_name', 'Marrickville'),
#               ('land_area', '581.3'),
#               ('population', '28223'),
#               ('number_of_dwellings', '7735'),
#               ('number_of_businesses', 3109)]),
#  OrderedDict([('area_id', '117021327'),
#               ('area_name', 'Petersham - Stanmore'),
#               ('land_area', '300.3'),
#               ('population', '21633'),
#               ('number_of_dwellings', '4947'),
#               ('number_of_businesses', 1917)]),
#  OrderedDict([('area_id', '117021328'),
#               ('area_name', 'Sydenham - Tempe - St Peters'),
#               ('land_area', '385.4'),
#               ('population', '8461'),
#               ('number_of_dwellings', '1757'),
#               ('number_of_businesses', 1087)]),
#  OrderedDict([('area_id', '117031329'),
#               ('area_name', 'Darlinghurst'),
#               ('land_area', '85.7'),
#               ('population', '12414'),
#               ('number_of_dwellings', '3914'),
#               ('number_of_businesses', 2260)]),
#  OrderedDict([('area_id', '117031330'),
#               ('area_name', 'Erskineville - Alexandria'),
#               ('land_area', '432'),
#               ('population', '17822'),
#               ('number_of_dwellings', '4374'),
#               ('number_of_businesses', 3218)]),
#  OrderedDict([('area_id', '117031331'),
#               ('area_name', 'Glebe - Forest Lodge'),
#               ('land_area', '230.2'),
#               ('population', '21592'),
#               ('number_of_dwellings', '5073'),
#               ('number_of_businesses', 1830)]),
#  OrderedDict([('area_id', '117031332'),
#               ('area_name', 'Newtown - Camperdown - Darlington'),
#               ('land_area', '328.1'),
#               ('population', '27450'),
#               ('number_of_dwellings', '5079'),
#               ('number_of_businesses', 2316)]),
#  OrderedDict([('area_id', '117031333'),
#               ('area_name', 'Potts Point - Woolloomooloo'),
#               ('land_area', '145.9'),
#               ('population', '23809'),
#               ('number_of_dwellings', '8751'),
#               ('number_of_businesses', 2874)]),
#  OrderedDict([('area_id', '117031334'),
#               ('area_name', 'Pyrmont - Ultimo'),
#               ('land_area', '149.1'),
#               ('population', '24083'),
#               ('number_of_dwellings', '7599'),
#               ('number_of_businesses', 3933)]),
#  OrderedDict([('area_id', '117031335'),
#               ('area_name', 'Redfern - Chippendale'),
#               ('land_area', '216.3'),
#               ('population', '25538'),
#               ('number_of_dwellings', '7230'),
#               ('number_of_businesses', 2350)]),
#  OrderedDict([('area_id', '117031336'),
#               ('area_name', 'Surry Hills'),
#               ('land_area', '131.6'),
#               ('population', '18064'),
#               ('number_of_dwellings', '5040'),
#               ('number_of_businesses', 4302)]),
#  OrderedDict([('area_id', '117031337'),
#               ('area_name', 'Sydney - Haymarket - The Rocks'),
#               ('land_area', '429.3'),
#               ('population', '31010'),
#               ('number_of_dwellings', '8963'),
#               ('number_of_businesses', 40285)]),
#  OrderedDict([('area_id', '117031338'),
#               ('area_name', 'Waterloo - Beaconsfield'),
#               ('land_area', '358.1'),
#               ('population', '37929'),
#               ('number_of_dwellings', '12544'),
#               ('number_of_businesses', 3597)]),
#  OrderedDict([('area_id', '118011339'),
#               ('area_name', 'Bondi - Tamarama - Bronte'),
#               ('land_area', '249.6'),
#               ('population', '20310'),
#               ('number_of_dwellings', '5913'),
#               ('number_of_businesses', 2183)]),
#  OrderedDict([('area_id', '118011340'),
#               ('area_name', 'Bondi Beach - North Bondi'),
#               ('land_area', '246.1'),
#               ('population', '22969'),
#               ('number_of_dwellings', '6486'),
#               ('number_of_businesses', 2575)]),
#  OrderedDict([('area_id', '118011341'),
#               ('area_name', 'Bondi Junction - Waverly'),
#               ('land_area', '252.3'),
#               ('population', '18314'),
#               ('number_of_dwellings', '4379'),
#               ('number_of_businesses', 3685)]),
#  OrderedDict([('area_id', '118011342'),
#               ('area_name', 'Centennial Park'),
#               ('land_area', '197.9'),
#               ('population', '3'),
#               ('number_of_dwellings', '0'),
#               ('number_of_businesses', 0)]),
#  OrderedDict([('area_id', '118011343'),
#               ('area_name', 'Double Bay - Bellevue Hill'),
#               ('land_area', '471.4'),
#               ('population', '27009'),
#               ('number_of_dwellings', '9187'),
#               ('number_of_businesses', 5016)]),
#  OrderedDict([('area_id', '118011344'),
#               ('area_name', 'Dover Heights'),
#               ('land_area', '187.1'),
#               ('population', '11583'),
#               ('number_of_dwellings', '3482'),
#               ('number_of_businesses', 1545)]),
#  OrderedDict([('area_id', '118011345'),
#               ('area_name', 'Paddington - Moore Park'),
#               ('land_area', '372.5'),
#               ('population', '16657'),
#               ('number_of_dwellings', '2815'),
#               ('number_of_businesses', 2463)]),
#  OrderedDict([('area_id', '118011346'),
#               ('area_name', 'Rose Bay - Vaucluse - Watsons Bay'),
#               ('land_area', '513.6'),
#               ('population', '12729'),
#               ('number_of_dwellings', '3668'),
#               ('number_of_businesses', 1950)]),
#  OrderedDict([('area_id', '118011347'),
#               ('area_name', 'Woollahra'),
#               ('land_area', '128.1'),
#               ('population', '8246'),
#               ('number_of_dwellings', '1960'),
#               ('number_of_businesses', 1384)]),
#  OrderedDict([('area_id', '118021348'),
#               ('area_name', 'Coogee - Clovelly'),
#               ('land_area', '383.6'),
#               ('population', '27729'),
#               ('number_of_dwellings', '8467'),
#               ('number_of_businesses', 2567)]),
#  OrderedDict([('area_id', '118021350'),
#               ('area_name', 'Malabar - La Perouse - Chifley'),
#               ('land_area', '1182.5'),
#               ('population', '26095'),
#               ('number_of_dwellings', '5879'),
#               ('number_of_businesses', 1800)]),
#  OrderedDict([('area_id', '118021564'),
#               ('area_name', 'Kensington (NSW)'),
#               ('land_area', '264.2'),
#               ('population', '16291'),
#               ('number_of_dwellings', '4270'),
#               ('number_of_businesses', 975)]),
#  OrderedDict([('area_id', '118021565'),
#               ('area_name', 'Kingsford'),
#               ('land_area', '201.4'),
#               ('population', '16860'),
#               ('number_of_dwellings', '4741'),
#               ('number_of_businesses', 1170)]),
#  OrderedDict([('area_id', '118021566'),
#               ('area_name', 'Maroubra - North'),
#               ('land_area', '181.1'),
#               ('population', '10437'),
#               ('number_of_dwellings', '2752'),
#               ('number_of_businesses', 1165)]),
#  OrderedDict([('area_id', '118021567'),
#               ('area_name', 'Maroubra - South'),
#               ('land_area', '206.5'),
#               ('population', '11314'),
#               ('number_of_dwellings', '3254'),
#               ('number_of_businesses', 945)]),
#  OrderedDict([('area_id', '118021568'),
#               ('area_name', 'Maroubra - West'),
#               ('land_area', '204.6'),
#               ('population', '10999'),
#               ('number_of_dwellings', '2932'),
#               ('number_of_businesses', 882)]),
#  OrderedDict([('area_id', '118021569'),
#               ('area_name', 'Randwick - North'),
#               ('land_area', '193.6'),
#               ('population', '18020'),
#               ('number_of_dwellings', '5623'),
#               ('number_of_businesses', 1638)]),
#  OrderedDict([('area_id', '118021570'),
#               ('area_name', 'Randwick - South'),
#               ('land_area', '337.3'),
#               ('population', '14238'),
#               ('number_of_dwellings', '3922'),
#               ('number_of_businesses', 1402)]),
#  OrderedDict([('area_id', '119011354'),
#               ('area_name', 'Bass Hill - Georges Hall'),
#               ('land_area', '891.6'),
#               ('population', '23154'),
#               ('number_of_dwellings', '5539'),
#               ('number_of_businesses', 1472)]),
#  OrderedDict([('area_id', '119011355'),
#               ('area_name', 'Chullora'),
#               ('land_area', '405'),
#               ('population', '1225'),
#               ('number_of_dwellings', '185'),
#               ('number_of_businesses', 465)]),
#  OrderedDict([('area_id', '119011356'),
#               ('area_name', 'Condell Park'),
#               ('land_area', '1000.4'),
#               ('population', '12180'),
#               ('number_of_dwellings', '2196'),
#               ('number_of_businesses', 2202)]),
#  OrderedDict([('area_id', '119011357'),
#               ('area_name', 'Greenacre - Mount Lewis'),
#               ('land_area', '698.2'),
#               ('population', '27588'),
#               ('number_of_dwellings', '5118'),
#               ('number_of_businesses', 2495)]),
#  OrderedDict([('area_id', '119011358'),
#               ('area_name', 'Padstow'),
#               ('land_area', '650.9'),
#               ('population', '17217'),
#               ('number_of_dwellings', '4230'),
#               ('number_of_businesses', 1495)]),
#  OrderedDict([('area_id', '119011359'),
#               ('area_name', 'Panania - Milperra - Picnic Point'),
#               ('land_area', '1439.1'),
#               ('population', '26873'),
#               ('number_of_dwellings', '6720'),
#               ('number_of_businesses', 1674)]),
#  OrderedDict([('area_id', '119011360'),
#               ('area_name', 'Revesby'),
#               ('land_area', '509.3'),
#               ('population', '17066'),
#               ('number_of_dwellings', '3770'),
#               ('number_of_businesses', 1051)]),
#  OrderedDict([('area_id', '119011361'),
#               ('area_name', 'Yagoona - Birrong'),
#               ('land_area', '556'),
#               ('population', '21834'),
#               ('number_of_dwellings', '5129'),
#               ('number_of_businesses', 1419)]),
#  OrderedDict([('area_id', '119011571'),
#               ('area_name', 'Bankstown - North'),
#               ('land_area', '274.1'),
#               ('population', '17318'),
#               ('number_of_dwellings', '4557'),
#               ('number_of_businesses', 1819)]),
#  OrderedDict([('area_id', '119011572'),
#               ('area_name', 'Bankstown - South'),
#               ('land_area', '442.3'),
#               ('population', '16956'),
#               ('number_of_dwellings', '3942'),
#               ('number_of_businesses', 1991)]),
#  OrderedDict([('area_id', '119021362'),
#               ('area_name', 'Belmore - Belfield'),
#               ('land_area', '451.4'),
#               ('population', '20127'),
#               ('number_of_dwellings', '5359'),
#               ('number_of_businesses', 1756)]),
#  OrderedDict([('area_id', '119021363'),
#               ('area_name', 'Canterbury (South) - Campsie'),
#               ('land_area', '477.8'),
#               ('population', '32907'),
#               ('number_of_dwellings', '8806'),
#               ('number_of_businesses', 3094)]),
#  OrderedDict([('area_id', '119021364'),
#               ('area_name', 'Kingsgrove (North) - Earlwood'),
#               ('land_area', '820.2'),
#               ('population', '25211'),
#               ('number_of_dwellings', '7047'),
#               ('number_of_businesses', 2677)]),
#  OrderedDict([('area_id', '119021366'),
#               ('area_name', 'Punchbowl'),
#               ('land_area', '524.6'),
#               ('population', '21935'),
#               ('number_of_dwellings', '4809'),
#               ('number_of_businesses', 2171)]),
#  OrderedDict([('area_id', '119021367'),
#               ('area_name', 'Roselands'),
#               ('land_area', '364.6'),
#               ('population', '14301'),
#               ('number_of_dwellings', '3581'),
#               ('number_of_businesses', 1167)]),
#  OrderedDict([('area_id', '119021573'),
#               ('area_name', 'Lakemba'),
#               ('land_area', '218.7'),
#               ('population', '18292'),
#               ('number_of_dwellings', '4685'),
#               ('number_of_businesses', 1742)]),
#  OrderedDict([('area_id', '119021574'),
#               ('area_name', 'Wiley Park'),
#               ('land_area', '139.3'),
#               ('population', '11030'),
#               ('number_of_dwellings', '2936'),
#               ('number_of_businesses', 910)]),
#  OrderedDict([('area_id', '119031368'),
#               ('area_name', 'Hurstville'),
#               ('land_area', '364'),
#               ('population', '25742'),
#               ('number_of_dwellings', '6691'),
#               ('number_of_businesses', 2992)]),
#  OrderedDict([('area_id', '119031369'),
#               ('area_name', 'Mortdale - Penshurst'),
#               ('land_area', '611.6'),
#               ('population', '25195'),
#               ('number_of_dwellings', '7066'),
#               ('number_of_businesses', 1719)]),
#  OrderedDict([('area_id', '119031370'),
#               ('area_name', 'Narwee - Beverly Hills'),
#               ('land_area', '339.1'),
#               ('population', '14587'),
#               ('number_of_dwellings', '3756'),
#               ('number_of_businesses', 1049)]),
#  OrderedDict([('area_id', '119031371'),
#               ('area_name', 'Oatley - Hurstville Grove'),
#               ('land_area', '435.5'),
#               ('population', '13401'),
#               ('number_of_dwellings', '3828'),
#               ('number_of_businesses', 1139)]),
#  OrderedDict([('area_id', '119031372'),
#               ('area_name', 'Peakhurst - Lugarno'),
#               ('land_area', '743.1'),
#               ('population', '19093'),
#               ('number_of_dwellings', '4893'),
#               ('number_of_businesses', 2180)]),
#  OrderedDict([('area_id', '119031373'),
#               ('area_name', 'Riverwood'),
#               ('land_area', '277.3'),
#               ('population', '11999'),
#               ('number_of_dwellings', '3620'),
#               ('number_of_businesses', 640)]),
#  OrderedDict([('area_id', '119031374'),
#               ('area_name', 'South Hurstville - Blakehurst'),
#               ('land_area', '624.9'),
#               ('population', '25433'),
#               ('number_of_dwellings', '6836'),
#               ('number_of_businesses', 2626)]),
#  OrderedDict([('area_id', '119041375'),
#               ('area_name', 'Arncliffe - Bardwell Valley'),
#               ('land_area', '499.3'),
#               ('population', '24873'),
#               ('number_of_dwellings', '6611'),
#               ('number_of_businesses', 1806)]),
#  OrderedDict([('area_id', '119041376'),
#               ('area_name', 'Bexley'),
#               ('land_area', '527.8'),
#               ('population', '28200'),
#               ('number_of_dwellings', '6726'),
#               ('number_of_businesses', 2132)]),
#  OrderedDict([('area_id', '119041377'),
#               ('area_name', 'Kingsgrove (South) - Bardwell Park'),
#               ('land_area', '378.7'),
#               ('population', '13463'),
#               ('number_of_dwellings', '3869'),
#               ('number_of_businesses', 1211)]),
#  OrderedDict([('area_id', '119041378'),
#               ('area_name', 'Kogarah'),
#               ('land_area', '222'),
#               ('population', '12226'),
#               ('number_of_dwellings', '3571'),
#               ('number_of_businesses', 1460)]),
#  OrderedDict([('area_id', '119041379'),
#               ('area_name', 'Kogarah Bay - Carlton - Allawah'),
#               ('land_area', '350.3'),
#               ('population', '16943'),
#               ('number_of_dwellings', '5239'),
#               ('number_of_businesses', 1517)]),
#  OrderedDict([('area_id', '119041380'),
#               ('area_name', 'Monterey - Brighton-le-Sands - Kyeemagh'),
#               ('land_area', '338'),
#               ('population', '14936'),
#               ('number_of_dwellings', '4649'),
#               ('number_of_businesses', 1363)]),
#  OrderedDict([('area_id', '119041381'),
#               ('area_name', 'Rockdale - Banksia'),
#               ('land_area', '357.6'),
#               ('population', '21722'),
#               ('number_of_dwellings', '6090'),
#               ('number_of_businesses', 2093)]),
#  OrderedDict([('area_id', '119041382'),
#               ('area_name', 'Sans Souci - Ramsgate'),
#               ('land_area', '461.2'),
#               ('population', '17093'),
#               ('number_of_dwellings', '4656'),
#               ('number_of_businesses', 1642)]),
#  OrderedDict([('area_id', '120011383'),
#               ('area_name', 'Concord - Mortlake - Cabarita'),
#               ('land_area', '631.9'),
#               ('population', '23069'),
#               ('number_of_dwellings', '6812'),
#               ('number_of_businesses', 2597)]),
#  OrderedDict([('area_id', '120011384'),
#               ('area_name', 'Concord West - North Strathfield'),
#               ('land_area', '510.3'),
#               ('population', '26782'),
#               ('number_of_dwellings', '8367'),
#               ('number_of_businesses', 2809)]),
#  OrderedDict([('area_id', '120011385'),
#               ('area_name', 'Drummoyne - Rodd Point'),
#               ('land_area', '370.5'),
#               ('population', '19385'),
#               ('number_of_dwellings', '6163'),
#               ('number_of_businesses', 2357)]),
#  OrderedDict([('area_id', '120011386'),
#               ('area_name', 'Five Dock - Abbotsford'),
#               ('land_area', '462'),
#               ('population', '21692'),
#               ('number_of_dwellings', '6800'),
#               ('number_of_businesses', 2635)]),
#  OrderedDict([('area_id', '120021387'),
#               ('area_name', 'Balmain'),
#               ('land_area', '258.2'),
#               ('population', '16863'),
#               ('number_of_dwellings', '2494'),
#               ('number_of_businesses', 2372)]),
#  OrderedDict([('area_id', '120021388'),
#               ('area_name', 'Leichhardt - Annandale'),
#               ('land_area', '447.2'),
#               ('population', '28402'),
#               ('number_of_dwellings', '4530'),
#               ('number_of_businesses', 3345)]),
#  OrderedDict([('area_id', '120021389'),
#               ('area_name', 'Lilyfield - Rozelle'),
#               ('land_area', '360.4'),
#               ('population', '15152'),
#               ('number_of_dwellings', '2835'),
#               ('number_of_businesses', 1803)]),
#  OrderedDict([('area_id', '120031390'),
#               ('area_name', 'Ashfield'),
#               ('land_area', '367'),
#               ('population', '26125'),
#               ('number_of_dwellings', '7870'),
#               ('number_of_businesses', 1947)]),
#  OrderedDict([('area_id', '120031391'),
#               ('area_name', 'Burwood - Croydon'),
#               ('land_area', '449.3'),
#               ('population', '26524'),
#               ('number_of_dwellings', '7053'),
#               ('number_of_businesses', 3477)]),
#  OrderedDict([('area_id', '120031392'),
#               ('area_name', 'Canterbury (North) - Ashbury'),
#               ('land_area', '302.8'),
#               ('population', '11425'),
#               ('number_of_dwellings', '3293'),
#               ('number_of_businesses', 869)]),
#  OrderedDict([('area_id', '120031393'),
#               ('area_name', 'Croydon Park - Enfield'),
#               ('land_area', '397.1'),
#               ('population', '17929'),
#               ('number_of_dwellings', '4264'),
#               ('number_of_businesses', 1560)]),
#  OrderedDict([('area_id', '120031394'),
#               ('area_name', 'Dulwich Hill - Lewisham'),
#               ('land_area', '270.2'),
#               ('population', '17904'),
#               ('number_of_dwellings', '5772'),
#               ('number_of_businesses', 1149)]),
#  OrderedDict([('area_id', '120031395'),
#               ('area_name', 'Haberfield - Summer Hill'),
#               ('land_area', '347.5'),
#               ('population', '14231'),
#               ('number_of_dwellings', '4200'),
#               ('number_of_businesses', 1340)]),
#  OrderedDict([('area_id', '120031396'),
#               ('area_name', 'Homebush'),
#               ('land_area', '384.3'),
#               ('population', '17810'),
#               ('number_of_dwellings', '4806'),
#               ('number_of_businesses', 2127)]),
#  OrderedDict([('area_id', '120031575'),
#               ('area_name', 'Strathfield'),
#               ('land_area', '645.2'),
#               ('population', '26813'),
#               ('number_of_dwellings', '7382'),
#               ('number_of_businesses', 3558)]),
#  OrderedDict([('area_id', '120031576'),
#               ('area_name', 'Strathfield South'),
#               ('land_area', '251.1'),
#               ('population', '3775'),
#               ('number_of_dwellings', '963'),
#               ('number_of_businesses', 574)]),
#  OrderedDict([('area_id', '121011398'),
#               ('area_name', 'Chatswood (East) - Artarmon'),
#               ('land_area', '506.8'),
#               ('population', '30778'),
#               ('number_of_dwellings', '9711'),
#               ('number_of_businesses', 5358)]),
#  OrderedDict([('area_id', '121011399'),
#               ('area_name', 'Chatswood (West) - Lane Cove North'),
#               ('land_area', '553.7'),
#               ('population', '22776'),
#               ('number_of_dwellings', '7327'),
#               ('number_of_businesses', 1851)]),
#  OrderedDict([('area_id', '121011400'),
#               ('area_name', 'Lane Cove - Greenwich'),
#               ('land_area', '905.6'),
#               ('population', '28619'),
#               ('number_of_dwellings', '9026'),
#               ('number_of_businesses', 3823)]),
#  OrderedDict([('area_id', '121011401'),
#               ('area_name', 'St Leonards - Naremburn'),
#               ('land_area', '276.1'),
#               ('population', '11400'),
#               ('number_of_dwellings', '3898'),
#               ('number_of_businesses', 3127)]),
#  OrderedDict([('area_id', '121011402'),
#               ('area_name', 'Willoughby - Castle Cove - Northbridge'),
#               ('land_area', '1075.2'),
#               ('population', '26858'),
#               ('number_of_dwellings', '7672'),
#               ('number_of_businesses', 3338)]),
#  OrderedDict([('area_id', '121021403'),
#               ('area_name', 'Asquith - Mount Colah'),
#               ('land_area', '3468.5'),
#               ('population', '19107'),
#               ('number_of_dwellings', '5524'),
#               ('number_of_businesses', 1510)]),
#  OrderedDict([('area_id', '121021404'),
#               ('area_name', 'Berowra - Brooklyn - Cowan'),
#               ('land_area', '8175.5'),
#               ('population', '12081'),
#               ('number_of_dwellings', '3642'),
#               ('number_of_businesses', 888)]),
#  OrderedDict([('area_id', '121021406'),
#               ('area_name', 'Normanhurst - Thornleigh - Westleigh'),
#               ('land_area', '998.8'),
#               ('population', '19161'),
#               ('number_of_dwellings', '5167'),
#               ('number_of_businesses', 1604)]),
#  OrderedDict([('area_id', '121021577'),
#               ('area_name', 'Hornsby - East'),
#               ('land_area', '256.9'),
#               ('population', '12568'),
#               ('number_of_dwellings', '4444'),
#               ('number_of_businesses', 1599)]),
#  OrderedDict([('area_id', '121021578'),
#               ('area_name', 'Hornsby - West'),
#               ('land_area', '629'),
#               ('population', '11215'),
#               ('number_of_dwellings', '3271'),
#               ('number_of_businesses', 778)]),
#  OrderedDict([('area_id', '121021579'),
#               ('area_name', 'Waitara - Wahroonga (West)'),
#               ('land_area', '211.2'),
#               ('population', '10394'),
#               ('number_of_dwellings', '3217'),
#               ('number_of_businesses', 697)]),
#  OrderedDict([('area_id', '121031407'),
#               ('area_name', 'Gordon - Killara'),
#               ('land_area', '1167.1'),
#               ('population', '22735'),
#               ('number_of_dwellings', '6810'),
#               ('number_of_businesses', 2819)]),
#  OrderedDict([('area_id', '121031408'),
#               ('area_name', 'Lindfield - Roseville'),
#               ('land_area', '1187.7'),
#               ('population', '24556'),
#               ('number_of_dwellings', '7422'),
#               ('number_of_businesses', 2797)]),
#  OrderedDict([('area_id', '121031409'),
#               ('area_name', 'Pymble'),
#               ('land_area', '1025.1'),
#               ('population', '17217'),
#               ('number_of_dwellings', '4975'),
#               ('number_of_businesses', 2271)]),
#  OrderedDict([('area_id', '121031410'),
#               ('area_name', 'St Ives'),
#               ('land_area', '1777.8'),
#               ('population', '21926'),
#               ('number_of_dwellings', '6225'),
#               ('number_of_businesses', 2386)]),
#  OrderedDict([('area_id', '121031411'),
#               ('area_name', 'Turramurra'),
#               ('land_area', '2064.3'),
#               ('population', '19956'),
#               ('number_of_dwellings', '6095'),
#               ('number_of_businesses', 2026)]),
#  OrderedDict([('area_id', '121031412'),
#               ('area_name', 'Wahroonga (East) - Warrawee'),
#               ('land_area', '1332.7'),
#               ('population', '18797'),
#               ('number_of_dwellings', '5395'),
#               ('number_of_businesses', 2148)]),
#  OrderedDict([('area_id', '121041413'),
#               ('area_name', 'Cremorne - Cammeray'),
#               ('land_area', '323.9'),
#               ('population', '20508'),
#               ('number_of_dwellings', '7190'),
#               ('number_of_businesses', 2276)]),
#  OrderedDict([('area_id', '121041414'),
#               ('area_name', 'Crows Nest - Waverton'),
#               ('land_area', '296.1'),
#               ('population', '19347'),
#               ('number_of_dwellings', '6259'),
#               ('number_of_businesses', 2958)]),
#  OrderedDict([('area_id', '121041415'),
#               ('area_name', 'Mosman'),
#               ('land_area', '865'),
#               ('population', '30465'),
#               ('number_of_dwellings', '9651'),
#               ('number_of_businesses', 4227)]),
#  OrderedDict([('area_id', '121041416'),
#               ('area_name', 'Neutral Bay - Kirribilli'),
#               ('land_area', '221.1'),
#               ('population', '19205'),
#               ('number_of_dwellings', '7298'),
#               ('number_of_businesses', 2872)]),
#  OrderedDict([('area_id', '121041417'),
#               ('area_name', 'North Sydney - Lavender Bay'),
#               ('land_area', '191.4'),
#               ('population', '11819'),
#               ('number_of_dwellings', '4079'),
#               ('number_of_businesses', 6928)]),
#  OrderedDict([('area_id', '122011418'),
#               ('area_name', 'Balgowlah - Clontarf - Seaforth'),
#               ('land_area', '761'),
#               ('population', '21485'),
#               ('number_of_dwellings', '5771'),
#               ('number_of_businesses', 2617)]),
#  OrderedDict([('area_id', '122011419'),
#               ('area_name', 'Manly - Fairlight'),
#               ('land_area', '673.5'),
#               ('population', '24022'),
#               ('number_of_dwellings', '7572'),
#               ('number_of_businesses', 3000)]),
#  OrderedDict([('area_id', '122021420'),
#               ('area_name', 'Avalon - Palm Beach'),
#               ('land_area', '860.6'),
#               ('population', '13134'),
#               ('number_of_dwellings', '4120'),
#               ('number_of_businesses', 1920)]),
#  OrderedDict([('area_id', '122021421'),
#               ('area_name', 'Bayview - Elanora Heights'),
#               ('land_area', '6458.3'),
#               ('population', '11357'),
#               ('number_of_dwellings', '3225'),
#               ('number_of_businesses', 1529)]),
#  OrderedDict([('area_id', '122021422'),
#               ('area_name', 'Newport - Bilgola'),
#               ('land_area', '579.8'),
#               ('population', '13935'),
#               ('number_of_dwellings', '4377'),
#               ('number_of_businesses', 1874)]),
#  OrderedDict([('area_id', '122021423'),
#               ('area_name', 'Warriewood - Mona Vale'),
#               ('land_area', '1166.3'),
#               ('population', '25557'),
#               ('number_of_dwellings', '6623'),
#               ('number_of_businesses', 3779)]),
#  OrderedDict([('area_id', '122031424'),
#               ('area_name', 'Beacon Hill - Narraweena'),
#               ('land_area', '434.1'),
#               ('population', '14623'),
#               ('number_of_dwellings', '3919'),
#               ('number_of_businesses', 1153)]),
#  OrderedDict([('area_id', '122031425'),
#               ('area_name', 'Cromer'),
#               ('land_area', '749.2'),
#               ('population', '7855'),
#               ('number_of_dwellings', '2247'),
#               ('number_of_businesses', 940)]),
#  OrderedDict([('area_id', '122031426'),
#               ('area_name', 'Dee Why - North Curl Curl'),
# ...
#               ('number_of_businesses', 5067)]),
#  OrderedDict([('area_id', '125041493'),
#               ('area_name', 'Toongabbie - Constitution Hill'),
#               ('land_area', '748'),
#               ('population', '22902'),
#               ('number_of_dwellings', '5689'),
#               ('number_of_businesses', 1466)]),
#  OrderedDict([('area_id', '125041494'),
#               ('area_name', 'Winston Hills'),
#               ('land_area', '434.8'),
#               ('population', '11207'),
#               ('number_of_dwellings', '3337'),
#               ('number_of_businesses', 810)]),
#  OrderedDict([('area_id', '125041588'),
#               ('area_name', 'Pendle Hill - Girraween'),
#               ('land_area', '446.2'),
#               ('population', '13775'),
#               ('number_of_dwellings', '2765'),
#               ('number_of_businesses', 1203)]),
#  OrderedDict([('area_id', '125041589'),
#               ('area_name', 'Wentworthville - Westmead'),
#               ('land_area', '393.6'),
#               ('population', '16807'),
#               ('number_of_dwellings', '4138'),
#               ('number_of_businesses', 1282)]),
#  OrderedDict([('area_id', '126011495'),
#               ('area_name', 'Epping - North Epping'),
#               ('land_area', '888.1'),
#               ('population', '28975'),
#               ('number_of_dwellings', '7994'),
#               ('number_of_businesses', 2598)]),
#  OrderedDict([('area_id', '126011496'),
#               ('area_name', 'Pennant Hills - Cheltenham'),
#               ('land_area', '1329.4'),
#               ('population', '21462'),
#               ('number_of_dwellings', '6076'),
#               ('number_of_businesses', 2050)]),
#  OrderedDict([('area_id', '126021497'),
#               ('area_name', 'Eastwood - Denistone'),
#               ('land_area', '782'),
#               ('population', '26634'),
#               ('number_of_dwellings', '6662'),
#               ('number_of_businesses', 2624)]),
#  OrderedDict([('area_id', '126021498'),
#               ('area_name', 'Gladesville - Huntleys Point'),
#               ('land_area', '471.6'),
#               ('population', '15284'),
#               ('number_of_dwellings', '4634'),
#               ('number_of_businesses', 2114)]),
#  OrderedDict([('area_id', '126021499'),
#               ('area_name', 'Hunters Hill - Woolwich'),
#               ('land_area', '415.1'),
#               ('population', '10876'),
#               ('number_of_dwellings', '2805'),
#               ('number_of_businesses', 1421)]),
#  OrderedDict([('area_id', '126021500'),
#               ('area_name', 'Macquarie Park - Marsfield'),
#               ('land_area', '1067.2'),
#               ('population', '23239'),
#               ('number_of_dwellings', '5028'),
#               ('number_of_businesses', 2077)]),
#  OrderedDict([('area_id', '126021501'),
#               ('area_name', 'North Ryde - East Ryde'),
#               ('land_area', '622.3'),
#               ('population', '12970'),
#               ('number_of_dwellings', '3434'),
#               ('number_of_businesses', 1285)]),
#  OrderedDict([('area_id', '126021503'),
#               ('area_name', 'West Ryde - Meadowbank'),
#               ('land_area', '479.2'),
#               ('population', '20901'),
#               ('number_of_dwellings', '6851'),
#               ('number_of_businesses', 1873)]),
#  OrderedDict([('area_id', '126021590'),
#               ('area_name', 'Putney'),
#               ('land_area', '151.9'),
#               ('population', '4315'),
#               ('number_of_dwellings', '1131'),
#               ('number_of_businesses', 554)]),
#  OrderedDict([('area_id', '126021591'),
#               ('area_name', 'Ryde'),
#               ('land_area', '726.8'),
#               ('population', '29885'),
#               ('number_of_dwellings', '8733'),
#               ('number_of_businesses', 2301)]),
#  OrderedDict([('area_id', '127011504'),
#               ('area_name', 'Ashcroft - Busby - Miller'),
#               ('land_area', '546.3'),
#               ('population', '17924'),
#               ('number_of_dwellings', '4854'),
#               ('number_of_businesses', 508)]),
#  OrderedDict([('area_id', '127011505'),
#               ('area_name', 'Austral - Greendale'),
#               ('land_area', '11071.5'),
#               ('population', '9121'),
#               ('number_of_dwellings', '2353'),
#               ('number_of_businesses', 1414)]),
#  OrderedDict([('area_id', '127011506'),
#               ('area_name', 'Cobbitty - Leppington'),
#               ('land_area', '13213.8'),
#               ('population', '22559'),
#               ('number_of_dwellings', '5119'),
#               ('number_of_businesses', 1555)]),
#  OrderedDict([('area_id', '127011592'),
#               ('area_name', 'Badgerys Creek'),
#               ('land_area', '1757.7'),
#               ('population', '62'),
#               ('number_of_dwellings', '18'),
#               ('number_of_businesses', 12)]),
#  OrderedDict([('area_id', '127011593'),
#               ('area_name', 'Cecil Hills'),
#               ('land_area', '374.8'),
#               ('population', '7321'),
#               ('number_of_dwellings', '1725'),
#               ('number_of_businesses', 586)]),
#  OrderedDict([('area_id', '127011594'),
#               ('area_name', 'Green Valley'),
#               ('land_area', '321.5'),
#               ('population', '13085'),
#               ('number_of_dwellings', '2752'),
#               ('number_of_businesses', 722)]),
#  OrderedDict([('area_id', '127011595'),
#               ('area_name', 'Hinchinbrook'),
#               ('land_area', '522.5'),
#               ('population', '13283'),
#               ('number_of_dwellings', '2843'),
#               ('number_of_businesses', 672)]),
#  OrderedDict([('area_id', '127011596'),
#               ('area_name', 'Hoxton Park - Carnes Hill - Horningsea Park'),
#               ('land_area', '412.6'),
#               ('population', '12536'),
#               ('number_of_dwellings', '2919'),
#               ('number_of_businesses', 633)]),
#  OrderedDict([('area_id', '127011597'),
#               ('area_name', 'West Hoxton - Middleton Grange'),
#               ('land_area', '926.3'),
#               ('population', '16582'),
#               ('number_of_dwellings', '3657'),
#               ('number_of_businesses', 1021)]),
#  OrderedDict([('area_id', '127021509'),
#               ('area_name', 'Bonnyrigg Heights - Bonnyrigg'),
#               ('land_area', '518.9'),
#               ('population', '16818'),
#               ('number_of_dwellings', '3758'),
#               ('number_of_businesses', 852)]),
#  OrderedDict([('area_id', '127021510'),
#               ('area_name', 'Bossley Park - Abbotsbury'),
#               ('land_area', '951.5'),
#               ('population', '19838'),
#               ('number_of_dwellings', '5043'),
#               ('number_of_businesses', 1364)]),
#  OrderedDict([('area_id', '127021511'),
#               ('area_name', 'Cabramatta - Lansvale'),
#               ('land_area', '759.6'),
#               ('population', '26089'),
#               ('number_of_dwellings', '5800'),
#               ('number_of_businesses', 1872)]),
#  OrderedDict([('area_id', '127021512'),
#               ('area_name', 'Cabramatta West - Mount Pritchard'),
#               ('land_area', '534.3'),
#               ('population', '18095'),
#               ('number_of_dwellings', '4337'),
#               ('number_of_businesses', 926)]),
#  OrderedDict([('area_id', '127021513'),
#               ('area_name', 'Canley Vale - Canley Heights'),
#               ('land_area', '541.6'),
#               ('population', '21874'),
#               ('number_of_dwellings', '4809'),
#               ('number_of_businesses', 1045)]),
#  OrderedDict([('area_id', '127021514'),
#               ('area_name', 'Edensor Park'),
#               ('land_area', '309.6'),
#               ('population', '10336'),
#               ('number_of_dwellings', '2448'),
#               ('number_of_businesses', 721)]),
#  OrderedDict([('area_id', '127021515'),
#               ('area_name', 'Fairfield'),
#               ('land_area', '423'),
#               ('population', '18664'),
#               ('number_of_dwellings', '4786'),
#               ('number_of_businesses', 1364)]),
#  OrderedDict([('area_id', '127021516'),
#               ('area_name', 'Fairfield - West'),
#               ('land_area', '469.2'),
#               ('population', '20214'),
#               ('number_of_dwellings', '4309'),
#               ('number_of_businesses', 959)]),
#  OrderedDict([('area_id', '127021517'),
#               ('area_name', 'Greenfield Park - Prairiewood'),
#               ('land_area', '363.7'),
#               ('population', '8716'),
#               ('number_of_dwellings', '2066'),
#               ('number_of_businesses', 493)]),
#  OrderedDict([('area_id', '127021518'),
#               ('area_name', 'Horsley Park - Kemps Creek'),
#               ('land_area', '5627.7'),
#               ('population', '4664'),
#               ('number_of_dwellings', '1150'),
#               ('number_of_businesses', 963)]),
#  OrderedDict([('area_id', '127021519'),
#               ('area_name', 'Smithfield - Wetherill Park'),
#               ('land_area', '661.2'),
#               ('population', '18918'),
#               ('number_of_dwellings', '4902'),
#               ('number_of_businesses', 1393)]),
#  OrderedDict([('area_id', '127021520'),
#               ('area_name', 'St Johns Park - Wakeley'),
#               ('land_area', '361.1'),
#               ('population', '11317'),
#               ('number_of_dwellings', '2721'),
#               ('number_of_businesses', 624)]),
#  OrderedDict([('area_id', '127021521'),
#               ('area_name', 'Wetherill Park Industrial'),
#               ('land_area', '855.7'),
#               ('population', '46'),
#               ('number_of_dwellings', '0'),
#               ('number_of_businesses', 1693)]),
#  OrderedDict([('area_id', '127031522'),
#               ('area_name', 'Casula'),
#               ('land_area', '707.2'),
#               ('population', '16488'),
#               ('number_of_dwellings', '3430'),
#               ('number_of_businesses', 1092)]),
#  OrderedDict([('area_id', '127031523'),
#               ('area_name', 'Chipping Norton - Moorebank'),
#               ('land_area', '1449'),
#               ('population', '19823'),
#               ('number_of_dwellings', '5132'),
#               ('number_of_businesses', 2431)]),
#  OrderedDict([('area_id', '127031524'),
#               ('area_name', 'Holsworthy - Wattle Grove'),
#               ('land_area', '7370'),
#               ('population', '21699'),
#               ('number_of_dwellings', '5392'),
#               ('number_of_businesses', 1148)]),
#  OrderedDict([('area_id', '127031598'),
#               ('area_name', 'Liverpool'),
#               ('land_area', '631.9'),
#               ('population', '29585'),
#               ('number_of_dwellings', '7443'),
#               ('number_of_businesses', 2589)]),
#  OrderedDict([('area_id', '127031599'),
#               ('area_name', 'Lurnea - Cartwright'),
#               ('land_area', '346.7'),
#               ('population', '12310'),
#               ('number_of_dwellings', '2897'),
#               ('number_of_businesses', 462)]),
#  OrderedDict([('area_id', '127031600'),
#               ('area_name', 'Prestons - Edmondson Park'),
#               ('land_area', '1413.2'),
#               ('population', '19219'),
#               ('number_of_dwellings', '4408'),
#               ('number_of_businesses', 1668)]),
#  OrderedDict([('area_id', '127031601'),
#               ('area_name', 'Warwick Farm'),
#               ('land_area', '465'),
#               ('population', '6470'),
#               ('number_of_dwellings', '1981'),
#               ('number_of_businesses', 330)]),
#  OrderedDict([('area_id', '128011529'),
#               ('area_name', 'Gymea - Grays Point'),
#               ('land_area', '579.8'),
#               ('population', '18057'),
#               ('number_of_dwellings', '5103'),
#               ('number_of_businesses', 1421)]),
#  OrderedDict([('area_id', '128011530'),
#               ('area_name', 'Miranda - Yowie Bay'),
#               ('land_area', '599.7'),
#               ('population', '18975'),
#               ('number_of_dwellings', '5471'),
#               ('number_of_businesses', 2217)]),
#  OrderedDict([('area_id', '128011531'),
#               ('area_name', 'Sylvania - Taren Point'),
#               ('land_area', '607.3'),
#               ('population', '16733'),
#               ('number_of_dwellings', '4449'),
#               ('number_of_businesses', 2301)]),
#  OrderedDict([('area_id', '128011602'),
#               ('area_name', 'Caringbah'),
#               ('land_area', '399.6'),
#               ('population', '12388'),
#               ('number_of_dwellings', '3441'),
#               ('number_of_businesses', 2052)]),
#  OrderedDict([('area_id', '128011603'),
#               ('area_name', 'Caringbah South'),
#               ('land_area', '407'),
#               ('population', '12572'),
#               ('number_of_dwellings', '3236'),
#               ('number_of_businesses', 1157)]),
#  OrderedDict([('area_id', '128011604'),
#               ('area_name', 'Cronulla - Kurnell - Bundeena'),
#               ('land_area', '2508.7'),
#               ('population', '24795'),
#               ('number_of_dwellings', '9038'),
#               ('number_of_businesses', 2485)]),
#  OrderedDict([('area_id', '128011605'),
#               ('area_name', 'Lilli Pilli - Port Hacking - Dolans Bay'),
#               ('land_area', '127.1'),
#               ('population', '3265'),
#               ('number_of_dwellings', '912'),
#               ('number_of_businesses', 442)]),
#  OrderedDict([('area_id', '128011606'),
#               ('area_name', 'Woolaware - Burraneer'),
#               ('land_area', '332.8'),
#               ('population', '8260'),
#               ('number_of_dwellings', '2143'),
#               ('number_of_businesses', 924)]),
#  OrderedDict([('area_id', '128021533'),
#               ('area_name', 'Heathcote - Waterfall'),
#               ('land_area', '2761.6'),
#               ('population', '6674'),
#               ('number_of_dwellings', '1964'),
#               ('number_of_businesses', 377)]),
#  OrderedDict([('area_id', '128021534'),
#               ('area_name', 'Illawong - Alfords Point'),
#               ('land_area', '729.8'),
#               ('population', '10756'),
#               ('number_of_dwellings', '3032'),
#               ('number_of_businesses', 1138)]),
#  OrderedDict([('area_id', '128021535'),
#               ('area_name', 'Menai - Lucas Heights - Woronora'),
#               ('land_area', '3340.5'),
#               ('population', '21656'),
#               ('number_of_dwellings', '5523'),
#               ('number_of_businesses', 1595)]),
#  OrderedDict([('area_id', '128021536'),
#               ('area_name', 'Oyster Bay - Como - Jannali'),
#               ('land_area', '890.5'),
#               ('population', '22084'),
#               ('number_of_dwellings', '5931'),
#               ('number_of_businesses', 1591)]),
#  OrderedDict([('area_id', '128021537'),
#               ('area_name', 'Royal National Park'),
#               ('land_area', '13933.4'),
#               ('population', '28'),
#               ('number_of_dwellings', '4'),
#               ('number_of_businesses', 3)]),
#  OrderedDict([('area_id', '128021538'),
#               ('area_name', 'Sutherland - Kirrawee'),
#               ('land_area', '775.5'),
#               ('population', '21760'),
#               ('number_of_dwellings', '6924'),
#               ('number_of_businesses', 2086)]),
#  OrderedDict([('area_id', '128021607'),
#               ('area_name', 'Engadine'),
#               ('land_area', '895.4'),
#               ('population', '17424'),
#               ('number_of_dwellings', '5219'),
#               ('number_of_businesses', 1121)]),
#  OrderedDict([('area_id', '128021608'),
#               ('area_name', 'Loftus - Yarrawarrah'),
#               ('land_area', '384.4'),
#               ('population', '7426'),
#               ('number_of_dwellings', '2177'),
#               ('number_of_businesses', 417)]),
#  OrderedDict([('area_id', '128021609'),
#               ('area_name', 'Woronora Heights'),
#               ('land_area', '313.7'),
#               ('population', '3681'),
#               ('number_of_dwellings', '1050'),
#               ('number_of_businesses', 259)])]

# %%
import requests
import json
def map_api(area_name):
    base_url = 'http://maps.googleapis.com/maps/api/geocode/json'
    my_params= {'address': area_name,'language':'en'}
    response = requests.get(base_url, params = my_params)

    #if()
    
    results      = response.json()['results']
    nhood_geo    = results[0]['geometry']['location']
    nhood_bounds = results[0]['geometry']['bounds']
    
    #check the raw response
    
    #print(my_params['address'])
    #print("Location: ", nhood_geo['lat'], nhood_geo['lng'])
    print("Boundary: ", json.dumps(nhood_bounds, indent=4))
    return nhood_bounds

# %%
for row in data_Neighbourhoods:
    boundary = map_api(row['area_name'])
    NE_lat = float(boundary['northeast']['lat'])
    NE_lng = float(boundary['northeast']['lng'])
    SW_lat = float(boundary['southwest']['lat'])
    SW_lng = float(boundary['southwest']['lng'])
    row.update({'boundry' : boundry_string})
    insert_stmt = """INSERT INTO Neighbourhoods(
                        area_id,
                         area_name,
                         land_area,
                         population,
                         number_of_dwellings,
                         number_of_businesses,
                         NE_lat,
                         NE_lng,
                         SW_lat,
                         SW_lng
                    ) 
                         VALUES (%(area_id)s, %(area_name)s, %(land_area)s,%(population)s, %(number_of_dwellings)s, %(number_of_businesses)s,%(NE_lat)s, %(NE_lng)s, %(SW_lat)s, %(SW_lng)s)"""
    pgexec (conn, insert_stmt, row, "row inserted")
# Out:
# Boundary:  {
#     "northeast": {
#         "lat": -33.4794739,
#         "lng": 151.4471164
#     },
#     "southwest": {
#         "lat": -33.4933219,
#         "lng": 151.4225143
#     }
# }
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5cebce634af2> in <module>()
#       5     SW_lat = float(boundary['southwest']['lat'])
#       6     SW_lng = float(boundary['southwest']['lng'])
# ----> 7     row.update({'boundry' : boundry_string})
#       8     insert_stmt = """INSERT INTO Neighbourhoods(
#       9                         area_id,
#
# NameError: name 'boundry_string' is not defined
